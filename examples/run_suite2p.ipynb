# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import suite2p

# %%
fnames = [
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240904\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240904\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240910\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240910\arm2',
    
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240918\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240918\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240924\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20240924\arm2',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20241118\arm1',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20241118\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R3\20241111\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R3\20241111\arm2',

    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20241106\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20241106\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20241118\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20241118\arm2',
]

# %%
ops = np.load(r'C:\Users\dirk\Documents\ibl_analysis\suite2p_all.npy', allow_pickle=True)
ops = ops.item()
ops['maxregshiftNR'] = 15.0

# %%
for fname in fnames:    
    db = {
        'data_path': [fname],
    }
    output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['Z:\\TM_Lab\\Edward\\Cerebellum_Imaging\\Pcp2-jgcamp8m\\J_L2\\20241118\\arm1']}
# tif
# ** Found 1 tifs - converting to binary **
# 2000 frames of binary, time 165.84 sec.
# 4000 frames of binary, time 243.97 sec.
# 6000 frames of binary, time 322.27 sec.
# 8000 frames of binary, time 400.65 sec.
# 10000 frames of binary, time 478.93 sec.
# 12000 frames of binary, time 559.98 sec.
# 14000 frames of binary, time 638.32 sec.
# 16000 frames of binary, time 716.59 sec.
# 18000 frames of binary, time 794.62 sec.
# 20000 frames of binary, time 872.62 sec.
# 22000 frames of binary, time 950.74 sec.
# 24000 frames of binary, time 1028.89 sec.
# 26000 frames of binary, time 1106.89 sec.
# 28000 frames of binary, time 1185.66 sec.
# 30000 frames of binary, time 1263.60 sec.
# 32000 frames of binary, time 1341.46 sec.
# time 1395.50 sec. Wrote 33181 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# ...
