# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import suite2p

# %%
fnames = [
    
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250903_valvesilent\arm1',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250903_valvesilent\arm2',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250909_valvesilent_punishsilent\arm1',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250909_valvesilent_punishsilent\arm2',

    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250702_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250702_valvesilent\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250710_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250710_valvesilent\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250716_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250716_valvesilent\arm2',

    
]

# %%
ops = np.load(r'C:\Users\dirk\Documents\ibl_analysis\suite2p_all.npy', allow_pickle=True)
ops = ops.item()
ops['maxregshiftNR'] = 15.0

# %%
#ops['reg_tif']=True
#ops['reg_tif']=True

# %%
print(ops)
# Out:
# {'suite2p_version': '0.14.2', 'look_one_level_down': 0.0, 'fast_disk': [], 'delete_bin': False, 'mesoscan': False, 'bruker': False, 'bruker_bidirectional': False, 'h5py': [], 'h5py_key': 'data', 'nwb_file': '', 'nwb_driver': '', 'nwb_series': '', 'save_path0': '', 'save_folder': [], 'subfolders': [], 'move_bin': False, 'nplanes': 1, 'nchannels': 1, 'functional_chan': 1, 'tau': 0.2, 'fs': 15.0, 'force_sktiff': False, 'frames_include': -1, 'multiplane_parallel': 0.0, 'ignore_flyback': [], 'preclassify': 0.0, 'save_mat': False, 'save_NWB': 0.0, 'combined': 1.0, 'aspect': 1.0, 'do_bidiphase': False, 'bidiphase': 0.0, 'bidi_corrected': False, 'do_registration': 1, 'two_step_registration': 0.0, 'keep_movie_raw': False, 'nimg_init': 300, 'batch_size': 500, 'maxregshift': 0.1, 'align_by_chan': 1, 'reg_tif': False, 'reg_tif_chan2': False, 'subpixel': 10, 'smooth_sigma_time': 0.0, 'smooth_sigma': 1.15, 'th_badframes': 1.0, 'norm_frames': True, 'force_refImg': False, 'pad_fft': False, 'nonrigid
# ...

# %%
for fname in fnames:    
    db = {
        'data_path': [fname],
    }
    output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['Z:\\TM_Lab\\Edward\\Cerebellum_Imaging\\Pcp2-jgcamp8m\\AE_L3\\20250903_valvesilent\\arm1']}
# FOUND BINARIES AND OPS IN ['Z:\\TM_Lab\\Edward\\Cerebellum_Imaging\\Pcp2-jgcamp8m\\AE_L3\\20250903_valvesilent\\arm1\\suite2p\\plane0\\ops.npy']
# removing previous detection and extraction files, if present
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# binary path: Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250903_valvesilent\arm1\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\dirk\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 07
# Binned movie of size [5330,1006,1000] created in 1159.25 sec.
# ROIs: 200, cost: 0.5504, time: 776.6288
# ROIs: 400, cost: 0.5350, time: 1061.6015
# ROIs: 600, cost: 0.5236, time: 1337.8570
# ROIs: 800, cost: 0.5139, time: 1618.6109
# ROIs: 1000, cost: 0.5055, time: 1898.7829
# ...
