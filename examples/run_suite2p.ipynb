# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import suite2p

# %%
fnames = [
    r'I:\Cerebellum_imaging_Dec2025\AE_L3\20250926_conflict_valvesilent\arm1',
    r'I:\Cerebellum_imaging_Dec2025\AE_L3\20250926_conflict_valvesilent\arm2',
    r'I:\Cerebellum_imaging_Dec2025\AE_L3\20250929_conflict_valvesilent\arm1',
    r'I:\Cerebellum_imaging_Dec2025\AE_L3\20250929_conflict_valvesilent\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250702_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250702_valvesilent\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250710_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250710_valvesilent\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250716_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AF_R2\20250716_valvesilent\arm2',

    
]

# %%
ops = np.load(r'C:\Users\dirk\Documents\ibl_analysis\suite2p_all.npy', allow_pickle=True)
ops = ops.item()
ops['maxregshiftNR'] = 15.0

# %%
#ops['reg_tif']=True
#ops['reg_tif']=True

# %%
print(ops)
# Out:
# {'suite2p_version': '0.14.2', 'look_one_level_down': 0.0, 'fast_disk': [], 'delete_bin': False, 'mesoscan': False, 'bruker': False, 'bruker_bidirectional': False, 'h5py': [], 'h5py_key': 'data', 'nwb_file': '', 'nwb_driver': '', 'nwb_series': '', 'save_path0': '', 'save_folder': [], 'subfolders': [], 'move_bin': False, 'nplanes': 1, 'nchannels': 1, 'functional_chan': 1, 'tau': 0.2, 'fs': 15.0, 'force_sktiff': False, 'frames_include': -1, 'multiplane_parallel': 0.0, 'ignore_flyback': [], 'preclassify': 0.0, 'save_mat': False, 'save_NWB': 0.0, 'combined': 1.0, 'aspect': 1.0, 'do_bidiphase': False, 'bidiphase': 0.0, 'bidi_corrected': False, 'do_registration': 1, 'two_step_registration': 0.0, 'keep_movie_raw': False, 'nimg_init': 300, 'batch_size': 500, 'maxregshift': 0.1, 'align_by_chan': 1, 'reg_tif': False, 'reg_tif_chan2': False, 'subpixel': 10, 'smooth_sigma_time': 0.0, 'smooth_sigma': 1.15, 'th_badframes': 1.0, 'norm_frames': True, 'force_refImg': False, 'pad_fft': False, 'nonrigid': True, 'block_size': [128, 128], 'snr_thresh': 1.2, 'maxregshiftNR': 15.0, '1Preg': False, 'spatial_hp_reg': 42.0, 'pre_smooth': 2.0, 'spatial_taper': 50.0, 'roidetect': True, 'spikedetect': True, 'sparse_mode': False, 'spatial_scale': 0, 'connected': True, 'nbinned': 5000, 'max_iterations': 20, 'threshold_scaling': 1.0, 'max_overlap': 0.5, 'high_pass': 100.0, 'spatial_hp_detect': 15.0, 'denoise': 0.0, 'anatomical_only': 0, 'diameter': 12, 'cellprob_threshold': 0.0, 'flow_threshold': 1.5, 'spatial_hp_cp': 0.0, 'pretrained_model': 'cyto', 'soma_crop': 1.0, 'neuropil_extract': True, 'inner_neuropil_radius': 2, 'min_neuropil_pixels': 350, 'lam_percentile': 50.0, 'allow_overlap': True, 'use_builtin_classifier': False, 'classifier_path': '', 'chan2_thres': 0.65, 'baseline': 'maximin', 'win_baseline': 60.0, 'sig_baseline': 10.0, 'prctile_baseline': 8.0, 'neucoeff': 0.7, 'input_format': 'tif'}

# %%
for fname in fnames:    
    db = {
        'data_path': [fname],
    }
    output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['I:\\Cerebellum_imaging_Dec2025\\AE_L3\\20250926_conflict_valvesilent\\arm1']}
# tif
# ** Found 1 tifs - converting to binary **
# 2000 frames of binary, time 85.70 sec.
# 4000 frames of binary, time 118.03 sec.
# 6000 frames of binary, time 150.45 sec.
# 8000 frames of binary, time 183.02 sec.
# 10000 frames of binary, time 214.80 sec.
# 12000 frames of binary, time 245.63 sec.
# 14000 frames of binary, time 275.61 sec.
# 16000 frames of binary, time 304.97 sec.
# 18000 frames of binary, time 336.95 sec.
# 20000 frames of binary, time 369.16 sec.
# 22000 frames of binary, time 400.99 sec.
# 24000 frames of binary, time 433.73 sec.
# 26000 frames of binary, time 466.32 sec.
# 28000 frames of binary, time 498.97 sec.
# 30000 frames of binary, time 531.82 sec.
# 32000 frames of binary, time 564.37 sec.
# 34000 frames of binary, time 597.07 sec.
# 36000 frames of binary, time 629.00 sec.
# 38000 frames of binary, time 661.45 sec.
# 40000 frames of binary, time 693.94 sec.
# 42000 frames of binary, time 726.60 sec.
# time 747.53 sec. Wrote 43239 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# NOTE: applying default C:\Users\dirk\.suite2p\classifiers\classifier_user.npy
# ----------- REGISTRATION
# Reference frame, 67.57 sec.
# Registered 500/43239 in 64.33s
# Registered 1000/43239 in 127.25s
# Registered 1500/43239 in 191.41s
# Registered 2000/43239 in 255.14s
# Registered 2500/43239 in 319.27s
# Registered 3000/43239 in 383.30s
# Registered 3500/43239 in 446.53s
# Registered 4000/43239 in 509.51s
# Registered 4500/43239 in 573.43s
# Registered 5000/43239 in 637.14s
# Registered 5500/43239 in 701.78s
# Registered 6000/43239 in 765.47s
# Registered 6500/43239 in 829.70s
# Registered 7000/43239 in 894.76s
# Registered 7500/43239 in 958.25s
# Registered 8000/43239 in 1021.71s
# Registered 8500/43239 in 1085.75s
# Registered 9000/43239 in 1149.50s
# ROIs: 400, cost: 0.5220, time: 1435.1001
# ROIs: 600, cost: 0.5159, time: 1770.4040
# ROIs: 800, cost: 0.5112, time: 2082.5705
# ROIs: 1000, cost: 0.5073, time: 2375.0315
# ROIs: 1047, cost: 0.5062, time: 2654.3237
# ROIs: 1056, cost: 0.5058, time: 2923.0130
# ROIs: 1056, cost: 0.5614, time: 3201.2728
# ROIs: 1056, cost: 0.5398, time: 3495.6980
# ROIs: 1056, cost: 0.5355, time: 3722.1628
# Detected 1056 ROIs, 4030.00 sec
# After removing overlaps, 768 ROIs remain
# ----------- Total 4244.25 sec.
# ----------- EXTRACTION
# Masks created, 73.87 sec.
# Extracted fluorescence from 768 ROIs in 43239 frames, 858.38 sec.
# ----------- Total 937.80 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.08 sec.
# Plane 0 processed in 11300.74 sec (can open in GUI).
# total = 12061.42 sec.
# TOTAL RUNTIME 12061.42 sec
# {'data_path': ['I:\\Cerebellum_imaging_Dec2025\\AE_L3\\20250926_conflict_valvesilent\\arm2']}
# tif
# ** Found 1 tifs - converting to binary **
# 2000 frames of binary, time 113.83 sec.
# 4000 frames of binary, time 145.50 sec.
# 6000 frames of binary, time 177.72 sec.
# 8000 frames of binary, time 209.21 sec.
# 10000 frames of binary, time 240.56 sec.
# 12000 frames of binary, time 271.91 sec.
# 14000 frames of binary, time 303.78 sec.
# 16000 frames of binary, time 335.80 sec.
# 18000 frames of binary, time 367.47 sec.
# 20000 frames of binary, time 398.99 sec.
# 22000 frames of binary, time 430.52 sec.
# 24000 frames of binary, time 462.31 sec.
# 26000 frames of binary, time 493.81 sec.
# 28000 frames of binary, time 525.94 sec.
# 30000 frames of binary, time 558.28 sec.
# 32000 frames of binary, time 590.60 sec.
# 34000 frames of binary, time 622.01 sec.
# 36000 frames of binary, time 653.40 sec.
# 38000 frames of binary, time 684.77 sec.
# 40000 frames of binary, time 715.98 sec.
# 42000 frames of binary, time 747.47 sec.
# time 768.35 sec. Wrote 43305 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# NOTE: applying default C:\Users\dirk\.suite2p\classifiers\classifier_user.npy
# ----------- REGISTRATION
# Reference frame, 67.15 sec.
# Registered 500/43305 in 64.18s
# Registered 1000/43305 in 128.65s
# Registered 1500/43305 in 192.60s
# Registered 2000/43305 in 256.61s
# Registered 2500/43305 in 320.86s
# Registered 3000/43305 in 384.80s
# Registered 3500/43305 in 448.14s
# Registered 4000/43305 in 511.41s
# Registered 4500/43305 in 574.44s
# Registered 5000/43305 in 637.63s
# Registered 5500/43305 in 701.40s
# Registered 6000/43305 in 765.05s
# Registered 6500/43305 in 828.83s
# Registered 7000/43305 in 892.08s
# Registered 7500/43305 in 955.81s
# Registered 8000/43305 in 1020.05s
# Registered 8500/43305 in 1084.27s
# Registered 9000/43305 in 1147.58s
# ROIs: 400, cost: 0.5308, time: 1282.3276
# ROIs: 600, cost: 0.5251, time: 1565.0357
# ROIs: 800, cost: 0.5208, time: 1821.2984
# ROIs: 1000, cost: 0.5171, time: 2077.1091
# ROIs: 1126, cost: 0.5150, time: 2319.3598
# ROIs: 1138, cost: 0.5145, time: 2549.6070
# ROIs: 1138, cost: 0.5522, time: 2891.1573
# ROIs: 1138, cost: 0.5340, time: 3148.8019
# ROIs: 1138, cost: 0.5306, time: 3356.3576
# Detected 1138 ROIs, 3636.95 sec
# After removing overlaps, 835 ROIs remain
# ----------- Total 3849.44 sec.
# ----------- EXTRACTION
# Masks created, 56.29 sec.
# Extracted fluorescence from 835 ROIs in 43305 frames, 860.11 sec.
# ----------- Total 920.03 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.29 sec.
# Plane 0 processed in 10877.90 sec (can open in GUI).
# total = 11658.39 sec.
# TOTAL RUNTIME 11658.39 sec
# {'data_path': ['I:\\Cerebellum_imaging_Dec2025\\AE_L3\\20250929_conflict_valvesilent\\arm1']}
# tif
# Could not find any tiffs
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 for fname in fnames:
#       2     db = {
#       3         'data_path': [fname],
#       4     }
# ----> 5     output_ops = suite2p.run_s2p(ops=ops, db=db)
#
# File c:\Users\dirk\anaconda3\envs\suite2p\lib\site-packages\suite2p\run_s2p.py:476, in run_s2p(ops, db, server)
#     474         ops0 = ops0[0]
#     475 else:
# --> 476     ops0 = io.tiff_to_binary(ops.copy())
#     478 plane_folders = natsorted([
#     479     f.path
#     480     for f in os.scandir(save_folder)
#     481     if f.is_dir() and f.name[:5] == "plane"
#     482 ])
#     483 ops_paths = [os.path.join(f, "ops.npy") for f in plane_folders]
#
# File c:\Users\dirk\anaconda3\envs\suite2p\lib\site-packages\suite2p\io\tiff.py:141, in tiff_to_binary(ops)
#     137 nchannels = ops1[0]["nchannels"]
#     139 # open all binary files for writing
#     140 # look for tiffs in all requested folders
# --> 141 ops1, fs, reg_file, reg_file_chan2 = utils.find_files_open_binaries(ops1, False)
#     142 ops = ops1[0]
#     143 # try tiff readers
#
# File c:\Users\dirk\anaconda3\envs\suite2p\lib\site-packages\suite2p\io\utils.py:254, in find_files_open_binaries(ops1, ish5)
#     251     print("\n".join(fs))
#     252 else:
#     253     # find tiffs
# --> 254     fs, ops2 = get_tif_list(ops1[0])
#     255     for ops in ops1:
#     256         ops["first_tiffs"] = ops2["first_tiffs"]
#
# File c:\Users\dirk\anaconda3\envs\suite2p\lib\site-packages\suite2p\io\utils.py:164, in get_tif_list(ops)
#     162 if len(fsall) == 0:
#     163     print("Could not find any tiffs")
# --> 164     raise Exception("no tiffs")
#     165 else:
#     166     ops["first_tiffs"] = np.array(first_tiffs).astype("bool")
#
# Exception: no tiffs
