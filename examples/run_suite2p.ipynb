# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import suite2p

# %%
fnames = [
    
    

    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250812_valvesilent\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250812_valvesilent\arm2',


    #r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250715_valvesilent\arm1',
    #r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L3\20250715_valvesilent\arm2',

    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AB_R2\20250617_valvesilent\arm1',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AB_R2\20250617_valvesilent\arm2',

    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AB_R2\20250625_valvesilent\arm1',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AB_R2\20250625_valvesilent\arm2',
    
]

# %%
ops = np.load(r'C:\Users\dirk\Documents\ibl_analysis\suite2p_all.npy', allow_pickle=True)
ops = ops.item()
ops['maxregshiftNR'] = 15.0

# %%
#ops['reg_tif']=True

# %%
print(ops)
# Out:
# {'suite2p_version': '0.14.2', 'look_one_level_down': 0.0, 'fast_disk': [], 'delete_bin': False, 'mesoscan': False, 'bruker': False, 'bruker_bidirectional': False, 'h5py': [], 'h5py_key': 'data', 'nwb_file': '', 'nwb_driver': '', 'nwb_series': '', 'save_path0': '', 'save_folder': [], 'subfolders': [], 'move_bin': False, 'nplanes': 1, 'nchannels': 1, 'functional_chan': 1, 'tau': 0.2, 'fs': 15.0, 'force_sktiff': False, 'frames_include': -1, 'multiplane_parallel': 0.0, 'ignore_flyback': [], 'preclassify': 0.0, 'save_mat': False, 'save_NWB': 0.0, 'combined': 1.0, 'aspect': 1.0, 'do_bidiphase': False, 'bidiphase': 0.0, 'bidi_corrected': False, 'do_registration': 1, 'two_step_registration': 0.0, 'keep_movie_raw': False, 'nimg_init': 300, 'batch_size': 500, 'maxregshift': 0.1, 'align_by_chan': 1, 'reg_tif': False, 'reg_tif_chan2': False, 'subpixel': 10, 'smooth_sigma_time': 0.0, 'smooth_sigma': 1.15, 'th_badframes': 1.0, 'norm_frames': True, 'force_refImg': False, 'pad_fft': False, 'nonrigid
# ...

# %%
for fname in fnames:    
    db = {
        'data_path': [fname],
    }
    output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['Z:\\TM_Lab\\Edward\\Cerebellum_Imaging\\Pcp2-jgcamp8m\\AB_R2\\20250617_valvesilent\\arm1']}
# tif
# ** Found 1 tifs - converting to binary **
# 2000 frames of binary, time 596.94 sec.
# 4000 frames of binary, time 674.14 sec.
# 6000 frames of binary, time 751.55 sec.
# 8000 frames of binary, time 828.95 sec.
# 10000 frames of binary, time 906.36 sec.
# 12000 frames of binary, time 983.78 sec.
# 14000 frames of binary, time 1061.08 sec.
# 16000 frames of binary, time 1138.49 sec.
# 18000 frames of binary, time 1221.05 sec.
# 20000 frames of binary, time 1298.14 sec.
# 22000 frames of binary, time 1375.66 sec.
# 24000 frames of binary, time 1453.00 sec.
# 26000 frames of binary, time 1530.22 sec.
# 28000 frames of binary, time 1607.55 sec.
# 30000 frames of binary, time 1684.89 sec.
# 32000 frames of binary, time 1761.89 sec.
# 34000 frames of binary, time 1839.37 sec.
# 36000 frames of binary, time 1916.63 sec.
# ...
