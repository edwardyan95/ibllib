# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import suite2p

# %%
fnames = [
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20241106\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20241106\arm2',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20241111\arm1',
    # r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\J_L2\20241111\arm2',
    r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20240821\arm1',
    #r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20240910\arm2',
    #r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20240924\arm1',
    #r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\A_R2\20240924\arm2',
]

# %%
ops = np.load(r'C:\Users\dirk\Documents\ibl_analysis\suite2p_all.npy', allow_pickle=True)
ops = ops.item()
ops['maxregshiftNR'] = 15.0

# %%
for fname in fnames:    
    db = {
        'data_path': [fname],
    }
    output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['Z:\\TM_Lab\\Edward\\Cerebellum_Imaging\\Pcp2-jgcamp8m\\A_R2\\20240821\\arm1']}
# tif
# ** Found 1 tifs - converting to binary **
# 2000 frames of binary, time 468.98 sec.
# 4000 frames of binary, time 547.34 sec.
# 6000 frames of binary, time 625.80 sec.
# 8000 frames of binary, time 704.81 sec.
# 10000 frames of binary, time 783.78 sec.
# 12000 frames of binary, time 862.81 sec.
# 14000 frames of binary, time 941.60 sec.
# 16000 frames of binary, time 1019.72 sec.
# 18000 frames of binary, time 1099.53 sec.
# 20000 frames of binary, time 1178.31 sec.
# 22000 frames of binary, time 1257.63 sec.
# 24000 frames of binary, time 1336.85 sec.
# 26000 frames of binary, time 1415.95 sec.
# 28000 frames of binary, time 1495.58 sec.
# 30000 frames of binary, time 1574.71 sec.
# 32000 frames of binary, time 1653.37 sec.
# 34000 frames of binary, time 1732.16 sec.
# 36000 frames of binary, time 1810.48 sec.
# 38000 frames of binary, time 1889.33 sec.
# ...
