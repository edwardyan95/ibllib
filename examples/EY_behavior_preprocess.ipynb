# %%
import sys
# sys.path.append(r'C:\Users\edwar\Documents\LabStuff\ibllib\brainbox\io')
#sys.path.append(r'C:\Users\IBL\Documents\ibl_analysis\ONE\one')
import matplotlib.pyplot as plt
import numpy as np
from brainbox.io.one import load_wheel_reaction_times
import brainbox.behavior.wheel as wh
from ibllib.io.raw_data_loaders import *
from ibllib.pipes.tasks import *
from ibllib.pipes import *
from ibllib.io.extractors.bpod_trials import *
from one.api import ONE
from one.alf.io import *

from ibllib.io.extractors.ephys_fpga import extract_wheel_moves
from ibllib.io.extractors.training_wheel import extract_first_movement_times
#from localAlf import load_wheel_reaction_times_local
from brainbox.behavior.training import *

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
# for datepath in os.listdir(subject_dir):
#     if '202' not in datepath:
#         continue
#     print(os.path.join(subject_dir, datepath))
#     datedir = os.path.join(subject_dir, datepath)
#     date = datedir[datedir.find(subject_id)+6:]
#     session_count = 0
#     for dir in os.listdir(datedir):
#         if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
#             continue
#         session_path = datedir + '\\' + dir
#         try:
#             temp_trial_data = load_object(session_path+'\\alf', 'trials')
#             break
#         except:
#             print('processing data for '+date)
#         try:
#             trials, wheel, output_files = extract_all(session_path, save=True)
#         except:
#             continue

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2'
subdir = [d for d in os.listdir(subject_dir)]
# subdir.index('2025-08-21')
subdir = subdir[:50]+subdir[53:54]+subdir[55:56]
print(subdir)
# Out:
# ['2025-05-28', '2025-05-29', '2025-05-30', '2025-06-06', '2025-06-09', '2025-06-10', '2025-06-11', '2025-06-12', '2025-06-13', '2025-06-16', '2025-06-17', '2025-06-18', '2025-06-19', '2025-06-20', '2025-06-23', '2025-06-24', '2025-06-25', '2025-06-26', '2025-06-27', '2025-06-30', '2025-07-01', '2025-07-02', '2025-07-03', '2025-07-04', '2025-07-07', '2025-07-08', '2025-07-09', '2025-07-10', '2025-07-11', '2025-07-14', '2025-07-15', '2025-07-16', '2025-07-17', '2025-07-18', '2025-07-21', '2025-07-22', '2025-07-23', '2025-07-24', '2025-07-25', '2025-07-27', '2025-07-28', '2025-07-29', '2025-07-30', '2025-07-31', '2025-08-01', '2025-08-04', '2025-08-05', '2025-08-06', '2025-08-07', '2025-08-08', '2025-08-14', '2025-08-21']

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
print(subject_id)
subdir = [d for d in os.listdir(subject_dir)]
subdir = subdir[:50]+subdir[53:54]+subdir[55:56]
trials_by_day = []
numTrial_by_day = []
all_trials={}
for datepath in subdir:
    print(os.path.join(subject_dir, datepath))
    if '202' not in datepath:
        continue
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+5:]
    date = date.replace('-','')
    date = date.replace('\\','')
    session_count = 0
    trial_data = []
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue

        session_path = datedir + '\\' + dir
        print(session_path)
        temp_trial_data = load_object(session_path+'\\alf', 'trials')
        numTrial = len(temp_trial_data['repNum'])
        
        # # Replace nans with zeros
        temp_trial_data.contrastRight[np.isnan(temp_trial_data.contrastRight)] = 0
        temp_trial_data.contrastLeft[np.isnan(temp_trial_data.contrastLeft)] = 0

        if session_count == 0:
            trial_data = temp_trial_data
        else:
            
            for k in trial_data.keys():
                trial_data[k] = np.concatenate(list(d[k] for d in [trial_data, temp_trial_data]))
        session_count += 1
        print('Number of trials in session#' + str(session_count) + ': ' + str(numTrial) )
    
    if len(trial_data) == 0:
        continue
    all_trials.update({date:trial_data})
    if os.path.exists(os.path.join(datedir, 'reaction_time.png')):
        continue
    # rt = trial_data['firstMovement_times'] - trial_data['stimOnTrigger_times']
    # plt.figure()
    # plt.plot(range(1,len(rt)+1), rt)
    # plt.title(subject_id+' '+date)
    # plt.xlabel('Trial#')
    # plt.ylabel('reaction time (s)')
    # plt.savefig(datedir+'\\reaction_time.png')
    #plt.show()

    # psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
    # plt.title(subject_id+' '+date)
    # psych_fig.savefig(datedir+'\\psychometric_curve.png')

    trial_correct_hist, bin_edges = np.histogram(np.where(trial_data['feedbackType'] == 1), bins=range(0, len(trial_data['feedbackType'])+1, 20))
    trial_correct_frac =  trial_correct_hist /20

    # plt.figure()
    # plt.plot(bin_edges[1:], trial_correct_frac, '-o')
    # plt.title(subject_id+' '+date)
    # plt.xlabel('20 trial blocks')
    # plt.ylabel('Percentage correct')
    # plt.savefig(datedir+'\\session_correct_progression.png')
    #plt.show()

#trials_all = concatenate_trials(all_trials)
# Out:
# AE_L2
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-05-28
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-05-29
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-05-30
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-10\001
# Number of trials in session#1: 153
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-11\001
# Number of trials in session#1: 160
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-12
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-12\001
# Number of trials in session#1: 32
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-12\002
# Number of trials in session#2: 130
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-13\001
# Number of trials in session#1: 200
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-16\001
# Number of trials in session#1: 233
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-17\001
# Number of trials in session#1: 274
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-18\001
# Number of trials in session#1: 260
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-19
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-19\001
# Number of trials in session#1: 328
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-20
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-20\001
# Number of trials in session#1: 262
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-23\001
# Number of trials in session#1: 257
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-24\002
# Number of trials in session#1: 11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-24\003
# Number of trials in session#2: 29
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-24\004
# Number of trials in session#3: 9
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-24\007
# Number of trials in session#4: 262
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-25\001
# Number of trials in session#1: 279
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-26
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-26\001
# Number of trials in session#1: 300
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-27\001
# Number of trials in session#1: 274
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-30
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-06-30\001
# Number of trials in session#1: 321
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-01
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-01\001
# Number of trials in session#1: 25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-01\002
# Number of trials in session#2: 295
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-02
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-02\001
# Number of trials in session#1: 309
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-03\001
# Number of trials in session#1: 3
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-03\002
# Number of trials in session#2: 357
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-04
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-04\002
# Number of trials in session#1: 347
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-07
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-07\001
# Number of trials in session#1: 392
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-08
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-08\001
# Number of trials in session#1: 258
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-09\001
# Number of trials in session#1: 287
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-10\002
# Number of trials in session#1: 325
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-11\001
# Number of trials in session#1: 360
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-14\001
# Number of trials in session#1: 418
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-15
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-15\001
# Number of trials in session#1: 9
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-15\002
# Number of trials in session#2: 339
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-16\002
# Number of trials in session#1: 5
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-16\003
# Number of trials in session#2: 379
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-17\001
# Number of trials in session#1: 358
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-18\001
# Number of trials in session#1: 396
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-21
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-21\001
# Number of trials in session#1: 403
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-22
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-22\002
# Number of trials in session#1: 411
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-23\001
# Number of trials in session#1: 440
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-24\002
# Number of trials in session#1: 475
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-25\002
# Number of trials in session#1: 361
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-27\001
# Number of trials in session#1: 59
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-27\002
# Number of trials in session#2: 280
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-28
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-28\001
# Number of trials in session#1: 370
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-29
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-29\001
# Number of trials in session#1: 326
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-30
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-30\001
# Number of trials in session#1: 361
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-31
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-07-31\001
# Number of trials in session#1: 381
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-01
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-01\001
# Number of trials in session#1: 353
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-04
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-04\001
# Number of trials in session#1: 296
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-05
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-05\001
# Number of trials in session#1: 302
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-06\001
# Number of trials in session#1: 318
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-07
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-07\001
# Number of trials in session#1: 333
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-08
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-08\001
# Number of trials in session#1: 237
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-14\001
# Number of trials in session#1: 312
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-21
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-21\003
# Number of trials in session#1: 254

# %%
accuracies = []
accuracies_vis = []
accuracies_aud = []
num_trials = []
training_dates = []
for date, trials in all_trials.items():
    #print(np.sum(trials['feedbackType'] == 1))
    #print(len(trials))
    if len(trials['feedbackType'])<50:
        continue
    try:
        accuracies.append(np.sum(trials['feedbackType'] == 1)/len(trials['feedbackType']))        
        accuracies_vis.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==0))/np.sum(trials['modality']==0))
        accuracies_aud.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==1))/np.sum(trials['modality']==1))
        num_trials.append(len(trials['feedbackType']))
        training_dates.append(date)
    except:
        continue
assert(len(training_dates)==len(accuracies_vis))
np.save(os.path.join(subject_dir, 'accuracies_vis.npy'), np.array(accuracies_vis)) 
np.save(os.path.join(subject_dir, 'accuracies_aud.npy'), np.array(accuracies_aud))
np.save(os.path.join(subject_dir, 'num_trials.npy'), np.array(num_trials))  
np.save(os.path.join(subject_dir, 'training_dates.npy'), np.array(training_dates))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 num_trials = []
#       5 training_dates = []
# ----> 6 for date, trials in all_trials.items():
#       7     #print(np.sum(trials['feedbackType'] == 1))
#       8     #print(len(trials))
#       9     if len(trials['feedbackType'])<50:
#      10         continue
#
# NameError: name 'all_trials' is not defined

# %%
len(accuracies_aud)
# Out:
# 47

# %%
accuracies = []
accuracies_vis = []
accuracies_aud = []
num_trials = []
for trials in all_trials.values():
    #print(np.sum(trials['feedbackType'] == 1))
    #print(len(trials))
    try:
        accuracies.append(np.sum(trials['feedbackType'] == 1)/len(trials['feedbackType']))        
        accuracies_vis.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==0))/np.sum(trials['modality']==0))
        accuracies_aud.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==1))/np.sum(trials['modality']==1))
        num_trials.append(len(trials['feedbackType']))
    except:
        continue
np.save(os.path.join(subject_dir, 'accuracies_vis.npy'), np.array(accuracies_vis)) 
np.save(os.path.join(subject_dir, 'accuracies_aud.npy'), np.array(accuracies_aud))
np.save(os.path.join(subject_dir, 'num_trials.npy'), np.array(num_trials))

# %%
mouse_ids = [
             'AB_R2',
             'AE_L2',
             'AE_L3',
             #'AF_R2',
             'AF_R3',
             'AF_L2',
             'AF_L3',
             'A_R2',
             'A_R3',
             'O_R2',
             'R_L2',
             'J_L2']
behav_data_folder = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects'
all_acc_vis = []
all_acc_aud = []
all_num_trials = []
for mouse in mouse_ids:
    mouse_path = os.path.join(behav_data_folder, mouse)
    acc_vis = np.load(os.path.join(mouse_path, 'accuracies_vis.npy'))
    acc_aud = np.load(os.path.join(mouse_path, 'accuracies_aud.npy'))
    num_trials = np.load(os.path.join(mouse_path, 'num_trials.npy'))
    all_acc_vis.append(acc_vis)
    all_acc_aud.append(acc_aud)
    all_num_trials.append(num_trials)

# %%
all_acc_vis[-3]
# Out:
# array([0.49166667, 0.44      , 0.43571429, 0.38888889, 0.4527027 ,
#        0.4379085 , 0.43949045, 0.48611111, 0.48461538, 0.435     ,
#        0.51      , 0.54705882, 0.59223301, 0.54615385, 0.41538462,
#        0.44886364, 0.52023121, 0.5375    , 0.5304878 , 0.51282051,
#        0.475     , 0.5       , 0.47857143, 0.46111111, 0.46511628,
#        0.48502994, 0.50625   , 0.525     , 0.50310559, 0.41104294,
#        0.42666667, 0.51666667, 0.43010753, 0.51530612, 0.42073171,
#        0.54455446, 0.51764706, 0.5       , 0.51363636, 0.545     ,
#        0.51955307, 0.53181818, 0.52542373, 0.47272727, 0.5047619 ,
#        0.45098039, 0.43684211, 0.54285714, 0.48947368, 0.565     ,
#        0.55555556, 0.54228856, 0.49763033, 0.6       , 0.6       ,
#        0.6043956 , 0.525     , 0.56111111, 0.55102041, 0.52777778,
#        0.56875   , 0.59635417, 0.6242236 , 0.58921162, 0.60287081,
#        0.60301508, 0.67630058, 0.58536585, 0.61818182, 0.63297872,
#        0.54594595, 0.55156951, 0.55555556, 0.53913043, 0.62      ,
#        0.42857143, 0.52272727, 0.5751073 , 0.5483871 , 0.56737589])

# %%
import matplotlib as mpl
mpl.rcParams['svg.fonttype'] = 'none'

# %%
max_length = 60

# Step 1: Clip or pad arrays to ensure all have the same length
def clip_or_pad(arr, max_length):
    return arr[:max_length] if len(arr) > max_length else np.pad(arr, (0, max_length - len(arr)), constant_values=np.nan)

# Use the same padding function for all arrays
all_acc_vis = np.array([clip_or_pad(arr, max_length) for arr in all_acc_vis])
all_acc_aud = np.array([clip_or_pad(arr, max_length) for arr in all_acc_aud])
all_num_trials = np.array([clip_or_pad(np.float32(arr), max_length) for arr in all_num_trials])

# Step 2: Compute the average and standard error for all conditions
avg_acc_vis = np.nanmean(all_acc_vis, axis=0)
avg_acc_aud = np.nanmean(all_acc_aud, axis=0)
avg_num_trials = np.nanmean(all_num_trials, axis=0)

n_valid_vis = np.sum(~np.isnan(all_acc_vis), axis=0)
n_valid_aud = np.sum(~np.isnan(all_acc_aud), axis=0)
n_valid_trials = np.sum(~np.isnan(all_num_trials), axis=0)

# Use ddof=1 for an unbiased estimate; set s.e.m. to NaN when n<=1
se_acc_vis = np.where(
    n_valid_vis > 1,
    np.nanstd(all_acc_vis, axis=0, ddof=1) / np.sqrt(n_valid_vis),
    np.nan
)
se_acc_aud = np.where(
    n_valid_aud > 1,
    np.nanstd(all_acc_aud, axis=0, ddof=1) / np.sqrt(n_valid_aud),
    np.nan
)
se_num_trials = np.where(
    n_valid_trials > 1,
    np.nanstd(all_num_trials, axis=0, ddof=1) / np.sqrt(n_valid_trials),
    np.nan
)

# Step 3: Create two subplots
from matplotlib.colors import to_rgba

# Example setup assuming all_acc_vis, all_acc_aud, all_num_trials already exist
x = np.arange(max_length)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

# Function to generate progressively lighter shades
def color_shades(base_color, n, alpha_min=0.2, alpha_max=0.6):
    """Generate n rgba colors with increasing alpha/saturation."""
    base = np.array(to_rgba(base_color))
    alphas = np.linspace(alpha_min, alpha_max, n)
    return [(*base[:3], a) for a in alphas]

# ---- INDIVIDUAL TRACES (shaded colors) ----
vis_shades = color_shades('#0072B2', len(all_acc_vis))
aud_shades = color_shades('#E69F00', len(all_acc_aud))

for i, y in enumerate(all_acc_vis):
    m = ~np.isnan(y)
    if m.any():
        ax1.plot(x[m], y[m], color=vis_shades[i], linewidth=1)

for i, y in enumerate(all_acc_aud):
    m = ~np.isnan(y)
    if m.any():
        ax1.plot(x[m], y[m], color=aud_shades[i], linewidth=1)

# ---- GROUP MEANS + S.E.M. ----
ax1.plot(x, avg_acc_vis, marker='o', color='#0072B2', lw=2.5, label='visual (mean)')
ax1.fill_between(x, avg_acc_vis - se_acc_vis, avg_acc_vis + se_acc_vis,
                 color='#0072B2', alpha=0.25)
ax1.plot(x, avg_acc_aud, marker='o', color='#E69F00', lw=2.5, label='auditory (mean)')
ax1.fill_between(x, avg_acc_aud - se_acc_aud, avg_acc_aud + se_acc_aud,
                 color='#E69F00', alpha=0.25)

ax1.set_xlabel('Days')
ax1.set_ylabel('Fraction Correct')
ax1.set_title('Training Performance (11 mice)')
ax1.legend()
ax1.grid(False)
ax1.set_xlim(0, max_length - 1)
ax1.set_ylim(0.25, 0.95)
# ---- INDIVIDUAL TRACES (Number of Trials) ----
trial_shades = color_shades('green', len(all_num_trials))
for i, y in enumerate(all_num_trials):
    m = ~np.isnan(y)
    if m.any():
        ax2.plot(x[m], y[m], color=trial_shades[i], linewidth=1)

# ---- MEAN + S.E.M. (# Trials) ----
ax2.plot(x, avg_num_trials, marker='o', color='green', lw=2.5, label='mean')
ax2.fill_between(x, avg_num_trials - se_num_trials, avg_num_trials + se_num_trials,
                 color='green', alpha=0.25)

ax2.set_xlabel('Days')
ax2.set_ylabel('Number of Trials')
ax2.legend()
ax2.grid(False)
ax2.set_xlim(0, max_length - 1)

plt.tight_layout()
plt.show()
# Print diagnostic information
# print("Number of valid samples at each timepoint (visual):")
# print(n_valid_vis)
# print("\nNumber of valid samples at each timepoint (auditory):")
# print(n_valid_aud)
# print("\nNumber of valid samples at each timepoint (trials):")
# print(n_valid_trials)
fig.savefig(
    os.path.join(r"Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\pub_fig\Fig1\training_performance.svg"),
    format='svg',
    dpi=300,
    bbox_inches='tight',
    transparent=True,   # optional: removes white background
    metadata={'Creator': 'Matplotlib'}
)

# %%
from scipy import stats

def compute_slopes(all_acc, max_length):
    """
    all_acc: shape (n_mice, max_length), NaN-padded
    returns: array of slopes (one per mouse)
    """
    x = np.arange(max_length)
    slopes = []

    for y in all_acc:
        m = ~np.isnan(y)
        if np.sum(m) > 5:  # require enough points
            slope, intercept, r, p, stderr = stats.linregress(x[m], y[m])
            slopes.append(slope)
        else:
            slopes.append(np.nan)

    return np.array(slopes)

slopes_vis = compute_slopes(all_acc_vis, max_length)
slopes_aud = compute_slopes(all_acc_aud, max_length)

# One-sample t-test vs 0
t_vis, p_vis = stats.ttest_1samp(slopes_vis, 0, nan_policy='omit')
t_aud, p_aud = stats.ttest_1samp(slopes_aud, 0, nan_policy='omit')

print(f"Visual learning slope: mean={np.nanmean(slopes_vis):.4f}, t={t_vis:.2f}, p={p_vis:.3e}")
print(f"Auditory learning slope: mean={np.nanmean(slopes_aud):.4f}, t={t_aud:.2f}, p={p_aud:.3e}")
# Out:
# Visual learning slope: mean=0.0048, t=6.10, p=1.157e-04
# Auditory learning slope: mean=0.0066, t=8.72, p=5.471e-06

# %%
mouse_ids = [
             'AB_R2',
             'AE_L2',
             'AE_L3',
             #'AF_R2',
             'AF_R3',
             'AF_L2',
             'AF_L3',
             'A_R2',
             'A_R3',
             'O_R2',
             'R_L2',
             'J_L2'
             ]
behav_data_folder = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects'
import os, re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba

# ---------- CONFIG ----------
rt_clip = (0.05, 20.0)   # keep RTs within [0.05s, 5s]
max_length = 60

col_vis = '#0072B2'     # visual color (consistent with your accuracy plot)
col_aud = '#E69F00'     # auditory color

# ---------- HELPERS ----------
def clip_or_pad(arr, L):
    arr = np.asarray(arr, float)
    if len(arr) >= L:
        return arr[:L]
    out = np.full(L, np.nan, float)
    out[:len(arr)] = arr
    return out

def color_shades(base_color, n, alpha_min=0.15, alpha_max=0.55):
    base = np.array(to_rgba(base_color))
    alphas = np.linspace(alpha_min, alpha_max, max(n, 1))
    return [(*base[:3], a) for a in alphas]

def extract_date_key(name):
    m = re.search(r'(20\d{6})', name)  # YYYYMMDD
    return m.group(1) if m else name

# ---------- COLLECT DAILY MEAN RT PER MOUSE, SPLIT BY MODALITY ----------
per_mouse_daily_rt_vis = {}  # mouse -> 1D array of daily mean RT (modality==0)
per_mouse_daily_rt_aud = {}  # mouse -> 1D array of daily mean RT (modality==1)

for mouse in mouse_ids:
    subject_dir = os.path.join(behav_data_folder, mouse)
    if not os.path.isdir(subject_dir):
        print(f"Missing subject dir: {subject_dir}")
        continue

    day_vis_means = []  # list of (date_key, mean_rt_vis)
    day_aud_means = []  # list of (date_key, mean_rt_aud)

    for datepath in os.listdir(subject_dir):
        if '202' not in datepath:
            continue
        datedir = os.path.join(subject_dir, datepath)
        if not os.path.isdir(datedir):
            continue

        sess_vis_means = []
        sess_aud_means = []

        for sess in os.listdir(datedir):
            if not os.path.exists(os.path.join(datedir, sess, 'raw_behavior_data', 'online_plot.png')):
                continue

            alf_dir = os.path.join(datedir, sess, 'alf')
            try:
                trials = load_object(alf_dir, 'trials')
                rt = np.asarray(trials['feedback_times'] - trials['stimOnTrigger_times'], float)
                mod = np.asarray(trials['modality'])

                # validity mask
                valid = np.isfinite(rt)
                if rt_clip is not None:
                    lo, hi = rt_clip
                    valid &= (rt >= lo) & (rt <= hi)

                # split by modality
                vis_mask = valid & (mod == 0)
                aud_mask = valid & (mod == 1)

                if np.any(vis_mask):
                    sess_vis_means.append(float(rt[vis_mask].mean()))
                if np.any(aud_mask):
                    sess_aud_means.append(float(rt[aud_mask].mean()))

            except Exception as e:
                print(f"{mouse} {datepath}/{sess}: error or no trials: {e}")

        # average across sessions for the day
        dk = extract_date_key(datepath)
        if sess_vis_means:
            day_vis_means.append((dk, float(np.mean(sess_vis_means))))
        if sess_aud_means:
            day_aud_means.append((dk, float(np.mean(sess_aud_means))))

    # sort chronologically and store series
    day_vis_means.sort(key=lambda t: t[0])
    day_aud_means.sort(key=lambda t: t[0])

    per_mouse_daily_rt_vis[mouse] = np.array([v for _, v in day_vis_means], float)
    per_mouse_daily_rt_aud[mouse] = np.array([v for _, v in day_aud_means], float)

# ---------- STACK, PAD/TRUNCATE ----------
all_rt_vis = np.array([clip_or_pad(per_mouse_daily_rt_vis[m], max_length)
                       for m in per_mouse_daily_rt_vis.keys()])
all_rt_aud = np.array([clip_or_pad(per_mouse_daily_rt_aud[m], max_length)
                       for m in per_mouse_daily_rt_aud.keys()])

# ---------- AGGREGATE ----------
avg_rt_vis = np.nanmean(all_rt_vis, axis=0)
avg_rt_aud = np.nanmean(all_rt_aud, axis=0)

n_valid_vis = np.sum(~np.isnan(all_rt_vis), axis=0)
n_valid_aud = np.sum(~np.isnan(all_rt_aud), axis=0)

se_rt_vis = np.where(n_valid_vis > 1,
                     np.nanstd(all_rt_vis, axis=0, ddof=1) / np.sqrt(n_valid_vis),
                     np.nan)
se_rt_aud = np.where(n_valid_aud > 1,
                     np.nanstd(all_rt_aud, axis=0, ddof=1) / np.sqrt(n_valid_aud),
                     np.nan)

# ---------- PLOT (individual shaded traces + mean ± s.e.m.) ----------
x = np.arange(max_length)
fig, ax = plt.subplots(1, 1, figsize=(6, 4.8))

# individuals
vis_shades = color_shades(col_vis, all_rt_vis.shape[0], 0.12, 0.45)
for i, y in enumerate(all_rt_vis):
    m = ~np.isnan(y)
    if m.any():
        ax.plot(x[m], y[m], linewidth=1, color=vis_shades[i])

aud_shades = color_shades(col_aud, all_rt_aud.shape[0], 0.12, 0.45)
for i, y in enumerate(all_rt_aud):
    m = ~np.isnan(y)
    if m.any():
        ax.plot(x[m], y[m], linewidth=1, color=aud_shades[i])

# group means + s.e.m.
mv = ~np.isnan(avg_rt_vis)
ma = ~np.isnan(avg_rt_aud)

ax.plot(x[mv], avg_rt_vis[mv], marker='o', lw=2.5, color=col_vis, label='visual (mean)')
ax.fill_between(x[mv],
                avg_rt_vis[mv] - se_rt_vis[mv],
                avg_rt_vis[mv] + se_rt_vis[mv],
                color=col_vis, alpha=0.25)

ax.plot(x[ma], avg_rt_aud[ma], marker='o', lw=2.5, color=col_aud, label='auditory (mean)')
ax.fill_between(x[ma],
                avg_rt_aud[ma] - se_rt_aud[ma],
                avg_rt_aud[ma] + se_rt_aud[ma],
                color=col_aud, alpha=0.25)

ax.set_xlabel('Days')
ax.set_ylabel('Reaction time (s)')
ax.set_title('Reaction Time Across Training (visual vs auditory)')
ax.set_xlim(0, max_length - 1)
ax.grid(False)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# AB_R2 2025-08-07/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AB_R2\2025-08-07\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# AB_R2 2025-08-08/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AB_R2\2025-08-08\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# AB_R2 2025-08-11/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AB_R2\2025-08-11\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# AB_R2 2025-08-12/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AB_R2\2025-08-12\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# AE_L2 2025-08-12/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-12\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# AE_L2 2025-08-18/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-18\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# AE_L2 2025-08-18/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L2\2025-08-18\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-08-13/001: error or no trials: 'modality'
# A_R2 2024-08-15/001: error or no trials: 'modality'
# A_R2 2024-11-19/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-19\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-11-22/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-22\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-11-25/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-25\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-11-26/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-26\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-11-27/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-27\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-11-28/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-28\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-11-29/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-11-29\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-02/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-02\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-03/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-03\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-04/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-04\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-05/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-05\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-06/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-06\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-09/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-09\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-10/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-10\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R2 2024-12-12/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R2\2024-12-12\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-11-22/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-11-22\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-11-25/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-11-25\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-11-26/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-11-26\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-11-27/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-11-27\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-11-28/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-11-28\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-11-29/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-11-29\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-12-02/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-12-02\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-12-03/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-12-03\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-12-04/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-12-04\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-12-05/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-12-05\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-12-06/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-12-06\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# A_R3 2024-12-09/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\A_R3\2024-12-09\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-12/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-12\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-12/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-12\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-13/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-13\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-18/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-18\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-19/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-19\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-20/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-20\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-21/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-21\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-24/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-24\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-24/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-24\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-25/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-25\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-26/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-26\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-27/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-27\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-02-28/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-28\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-03-03/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-03-03\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-03-04/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-03-04\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-03-05/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-03-05\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# R_L2 2025-03-06/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-03-06\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-19/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-19\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-19/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-19\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-19/005: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-19\005\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-20/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-20\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-25/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-25\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-26/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-26\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-27/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-27\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-28/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-28\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-11-29/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-11-29\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-02/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-02\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-02/002: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-02\002\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-03/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-03\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-04/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-04\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-05/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-05\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-05/003: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-05\003\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-06/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-06\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-09/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-09\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-10/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-10\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-11/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-11\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-12/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-12\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`
# J_L2 2024-12-13/001: error or no trials: No object "trials" found in Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\J_L2\2024-12-13\001\alf
#  The ALF object was not found.  This may occur if the object or namespace or incorrectly formatted e.g. the object "_ibl_trials.intervals.npy" would be found with the filters `object="trials", namespace="ibl"`

# %%
def compute_slopes(y_mat, max_length):
    """
    y_mat: array (n_mice, max_length) with NaNs for missing days
    returns: slopes (one per mouse), in units of y-units per day
    """
    x = np.arange(max_length, dtype=float)
    slopes = np.full(y_mat.shape[0], np.nan, float)

    for i, y in enumerate(y_mat):
        m = np.isfinite(y)
        if np.sum(m) >= 6:  # require enough days to estimate a slope
            slope, intercept, r, p, stderr = stats.linregress(x[m], y[m])
            slopes[i] = slope

    return slopes

# --- per-mouse RT slopes (sec/day) ---
slopes_rt_vis = compute_slopes(all_rt_vis, max_length)
slopes_rt_aud = compute_slopes(all_rt_aud, max_length)

# --- one-sample t-tests vs 0 (expect negative) ---
t_vis, p_vis_two = stats.ttest_1samp(slopes_rt_vis, 0, nan_policy='omit')
t_aud, p_aud_two = stats.ttest_1samp(slopes_rt_aud, 0, nan_policy='omit')

# Optional: one-sided p-values for "slope < 0"
def p_one_sided_less(t_stat, p_two_sided):
    return p_two_sided / 2 if t_stat < 0 else 1 - (p_two_sided / 2)

p_vis = p_one_sided_less(t_vis, p_vis_two)
p_aud = p_one_sided_less(t_aud, p_aud_two)

print(f"Visual RT slope: mean={np.nanmean(slopes_rt_vis):.4f} s/day, t={t_vis:.2f}, p(two)={p_vis_two:.3e}, p(one, <0)={p_vis:.3e}")
print(f"Auditory RT slope: mean={np.nanmean(slopes_rt_aud):.4f} s/day, t={t_aud:.2f}, p(two)={p_aud_two:.3e}, p(one, <0)={p_aud:.3e}")

# --- optional: compare modality-specific RT slopes (paired) ---
t_mod, p_mod = stats.ttest_rel(slopes_rt_vis, slopes_rt_aud, nan_policy='omit')
print(f"Visual vs Auditory RT slope comparison: t={t_mod:.2f}, p={p_mod:.3e}")
# Out:
# Visual RT slope: mean=-0.0790 s/day, t=-8.01, p(two)=1.163e-05, p(one, <0)=5.817e-06
# Auditory RT slope: mean=-0.0606 s/day, t=-6.59, p(two)=6.137e-05, p(one, <0)=3.069e-05
# Visual vs Auditory RT slope comparison: t=-5.04, p=5.067e-04

# %%
fig.savefig(
    os.path.join(r"Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\pub_fig\Fig1\reaction_time.svg"),
    format='svg',
    dpi=300,
    bbox_inches='tight',
    transparent=True,   # optional: removes white background
    metadata={'Creator': 'Matplotlib'}
)

# %%
temp_trial_data['modality']
# Out:
# array([1.7703, 1.2686, 1.899 , 0.7482, 1.26  , 0.2223, 0.1736, 0.1793,
#        0.2465, 0.193 , 0.8008, 0.2583, 0.1973, 0.784 , 0.3067, 0.3388,
#        0.1956, 0.2766, 0.968 , 0.1744, 0.2256, 1.0357, 1.0487, 0.462 ,
#        0.6308, 0.3993, 0.2678, 0.2849, 0.6394, 0.4636, 0.3524, 1.7406,
#        0.3814, 0.2154, 0.2153, 3.3405, 0.9826, 5.8719, 0.1851, 2.7526,
#        0.3403, 1.8495, 0.1893, 0.6092, 0.501 , 0.3581, 0.1523, 0.1804,
#        0.1987, 0.1483, 0.5747, 0.2128, 0.5366, 0.2228, 0.1875, 0.1906,
#        0.3541, 0.3389, 0.2048, 2.7283, 0.1793, 0.6308, 0.1808, 0.2082,
#        0.1501, 0.2106, 0.1589, 0.3635, 0.1969, 0.4415, 0.9473, 0.2466,
#        0.2476, 2.3577, 0.1659, 0.2459, 0.2149, 0.2541, 0.263 , 0.3318,
#        0.223 , 0.2548, 0.2361, 0.5763, 0.4458, 0.3162, 0.1558, 0.5746,
#        0.3899, 0.1907])

# %%
mouse_path = r'Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\AE_L2'
subdir = [d for d in os.listdir(mouse_path)]
img_dates = [s for s in subdir if (
    s.isdigit() or 
    s.endswith('_valvesilent') and s.replace('_valvesilent', '').isdigit() or
    s.endswith('_valvesilent_punishsilent') and s.replace('_valvesilent_punishsilent', '').isdigit()
)]
img_dates = [d[:8] for d in img_dates]

# %%
img_dates
# Out:
# ['20250612',
#  '20250624',
#  '20250701',
#  '20250708',
#  '20250715',
#  '20250729',
#  '20250814',
#  '20250821']

# %%
accuracies_vis = np.load(os.path.join(subject_dir, 'accuracies_vis.npy'))
accuracies_aud = np.load(os.path.join(subject_dir, 'accuracies_aud.npy'))
num_trials = np.load(os.path.join(subject_dir, 'num_trials.npy'))
training_dates = np.load(os.path.join(subject_dir, 'training_dates.npy'))

# %%
training_dates
# Out:
# array(['20250610', '20250611', '20250612', '20250613', '20250616',
#        '20250617', '20250618', '20250619', '20250620', '20250623',
#        '20250624', '20250625', '20250626', '20250627', '20250630',
#        '20250701', '20250702', '20250703', '20250704', '20250707',
#        '20250708', '20250709', '20250710', '20250711', '20250714',
#        '20250715', '20250716', '20250717', '20250718', '20250721',
#        '20250722', '20250723', '20250724', '20250725', '20250727',
#        '20250728', '20250729', '20250730', '20250731', '20250801',
#        '20250804', '20250805', '20250806', '20250807', '20250808',
#        '20250814', '20250821'], dtype='<U8')

# %%
[np.where(training_dates == element)[0][0] for element in img_dates]
# Out:
# [2, 10, 15, 20, 25, 36, 45, 46]

# %%
img_dates
# Out:
# []

# %%
#training_dates = [element.replace('-', '') for element in training_dates]
imgday_indices = [np.where(training_dates == element)[0][0] for element in img_dates]
# Plotting
fig, axs = plt.subplots(2, 1, figsize=(5, 5))

# Plot lines and scatter points on the first axis
days = np.arange(1, len(num_trials) + 1)
axs[0].plot(days, accuracies_vis, label='vis trials', color='#0072B2')
axs[0].scatter(days, accuracies_vis, color='#0072B2')
axs[0].plot(days, accuracies_aud, label='aud trials', color='#E69F00')
axs[0].scatter(days, accuracies_aud, color='#E69F00')
axs[0].set_ylabel('Correct Choice %')
axs[0].set_xlabel('Training Days')
axs[0].set_xticks(np.arange(1, len(num_trials) + 1, 5))
#axs[0].set_yticklabels([str(x) for x in range(0,101,20)])
axs[0].set_title(subject_id)
axs[0].legend()

axs[1].plot(days, num_trials, color='green', marker='o')
axs[1].set_ylabel('Number of Trials')
axs[1].set_xlabel('Training Days')
axs[1].set_xticks(np.arange(1, len(num_trials) + 1, 5))
for ind in imgday_indices:
    axs[0].axvline(x=ind, color='gray', linestyle='--')

plt.tight_layout()


plt.savefig(os.path.join(subject_dir, 'training_summary.png'),dpi=300)

# %%
fig.savefig(
    os.path.join(r"Z:\TM_Lab\Edward\Cerebellum_Imaging\Pcp2-jgcamp8m\pub_fig\Fig3\AE_L2_training_performance.svg"),
    format='svg',
    dpi=300,
    bbox_inches='tight',
    transparent=True,   # optional: removes white background
    metadata={'Creator': 'Matplotlib'}
)

# %%
stages = ['Trial Start', 'Stimulus Presentation', 'Response Window', 'Decision and Feedback', 'Inter-Trial Interval']
durations = [1, 2, 1, 1, 2]  # Example durations in seconds

# Calculate the cumulative end times for each stage
end_times = [sum(durations[:i+1]) for i in range(len(durations))]
start_times = [0] + end_times[:-1]

# Create the plot
fig, ax = plt.subplots(figsize=(12, 2))

# Plot each stage as a horizontal line segment
for start, end, stage in zip(start_times, end_times, stages):
    ax.plot([start, end], [0.5, 0.5], marker='|', markersize=20, color='tab:blue')
    ax.text((start + end) / 2, 0.55, stage, ha='center', va='bottom', fontsize=10)

# Formatting the plot
ax.set_ylim(0, 1)
ax.set_yticks([])
ax.set_xlim(0, end_times[-1])
ax.set_xticks(start_times + [end_times[-1]])
ax.set_xticklabels(start_times + [end_times[-1]])
ax.set_xlabel('Time (s)')
ax.set_title('IBL Decision-Making Task Structure in a Trial')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### The movements algorithm
# The wheel movement onsets and offsets are calculated using the `wheel.movements` function.  The output of this function is saved in the 'wheelMoves' ALF.
#
# Refer to the `wheel.movements` function docstring for details of how the movements are detected.  In addition to the data found in the wheelMoves object, the function outputs an array of peak velocity times.  Also the function has a `make_plots` flag which will produce plots of the wheel position and velocity with the movement onsets and offsets highlighted (see below).
#
# The movements algorithm requires the positions and timestamps to be evenly sampled so they should be interpolated first, which can be done with the `wheel.interpolate_position` function.  The default sampling frequency is 1000Hz:

# %%
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position)
sec = 1000  # Number of seconds to plot
plt.figure()

# Plot the interpolated data points
mask = t < (t[0] + sec)
plt.plot(t[mask], pos[mask], '.', markeredgecolor='lightgrey', markersize=1)

# Plot the original data
mask = wheel.timestamps < (wheel.timestamps[0] + sec)
plt.plot(wheel.timestamps[mask], wheel.position[mask], 'r+', markersize=6)

# Labels etc.
plt.xlabel('time / sec')
plt.ylabel('position / rad')
plt.box(on=None)
plt.show()

# %%
# Convert the pos threshold defaults from samples to correct unit
thresholds_cm = wh.samples_to_cm(np.array([8, 1.5]), resolution=wh.ENC_RES)
thresholds = wh.cm_to_rad(thresholds_cm)
mask = t < (t[0] + sec)

onsets, offsets, peak_amp, peak_vel_times = wh.movements(
    t[mask], pos[mask], pos_thresh=thresholds[0], pos_thresh_onset=thresholds[0], make_plots=True)
plt.show()

# %%
rt = load_wheel_reaction_times_local(session_path+'\\alf')
trial_data = load_object(session_path+'\\alf', 'trials')

# # Replace nans with zeros
trial_data.contrastRight[np.isnan(trial_data.contrastRight)] = 0
trial_data.contrastLeft[np.isnan(trial_data.contrastLeft)] = 0

contrast = trial_data.contrastRight - trial_data.contrastLeft
mean_rt = [np.nanmean(rt[contrast == c]) for c in set(contrast)]

# RT may be nan if there were no detected movements, or if the goCue or stimOn times were nan
xdata = np.unique(contrast)
plt.figure(figsize=(4, 3))  # Some sort of strange behaviour in this cell's output
plt.plot(xdata, mean_rt);

plt.xlabel('contrast')
plt.ylabel('mean rt / s')
plt.ylim(bottom=0);
plt.show()

# %%
Fs = 1000
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position, freq=Fs)
vel, acc = wh.velocity_smoothed(pos, Fs)
n = 50
on, off = wheel_moves['intervals'][n,]
mask = np.logical_and(t > on, t < off)
sng = np.sign(vel[mask])
idx, = np.where(np.diff(sng) != 0)

plt.figure()
plt.plot(t[mask], pos[mask], 'k')
for i in idx:
    plt.axvline(x=t[mask][i], color='k', linestyle=':')

plt.title('Movement #%s' % n)
plt.xlabel('time / s')
plt.ylabel('position / rad');
plt.show()

# %%
n_trials = 5  # Number of trials to plot
# Randomly select the trials to plot
trial_ids = np.random.randint(trial_data['choice'].size, size=n_trials)
fig, axs = plt.subplots(1, n_trials, figsize=(8.5,2.5))
plt.tight_layout()

# Plot go cue and response times
goCues = trial_data['goCue_times'][trial_ids]
responses = trial_data['response_times'][trial_ids]

# Plot traces between trial intervals
starts = trial_data['intervals'][trial_ids, 0]
ends = trial_data['intervals'][trial_ids, 1]
# Cut up the wheel vectors
traces = wh.traces_by_trial(t, pos, start=starts, end=ends)
zipped = zip(traces, axs, goCues, responses, trial_ids)

for (trace, ax, go, resp, n) in zipped:
    ax.plot(trace[0], trace[1], 'k-')
    ax.axvline(x=go, color='g', label='go cue', linestyle=':')
    ax.axvline(x=resp, color='r', label='threshold', linestyle=':')
    ax.set_title('Trial #%s' % n)

    # Turn off tick labels
    ax.set_yticklabels([])
    ax.set_xticklabels([])

# Add labels to first
axs[0].set_xlabel('time / sec')
axs[0].set_ylabel('position / rad')
plt.legend();
plt.tight_layout()
plt.show()

# %%
psych = compute_psychometric(trial_data, signed_contrast=None, block=None, plotting=True, compute_ci=False, alpha=0.32)

# %%
psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
plt.title(subject_id+' '+date)
psych_fig.savefig(session_path+'\\psychometric_curve.png')

# %%
plt.plot(range(1,len(rt)+1), rt)
plt.title(subject_id+' '+date)
plt.xlabel('Trial#')
plt.ylabel('reaction time (s)')
plt.savefig(session_path+'\\reaction_time.png')
plt.show()
