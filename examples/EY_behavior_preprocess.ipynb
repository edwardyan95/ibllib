# %%
import sys
# sys.path.append(r'C:\Users\edwar\Documents\LabStuff\ibllib\brainbox\io')
#sys.path.append(r'C:\Users\IBL\Documents\ibl_analysis\ONE\one')
import matplotlib.pyplot as plt
import numpy as np
from brainbox.io.one import load_wheel_reaction_times
import brainbox.behavior.wheel as wh
from ibllib.io.raw_data_loaders import *
from ibllib.pipes.tasks import *
from ibllib.pipes import *
from ibllib.io.extractors.bpod_trials import *
from one.api import ONE
from one.alf.io import *

from ibllib.io.extractors.ephys_fpga import extract_wheel_moves
from ibllib.io.extractors.training_wheel import extract_first_movement_times
#from localAlf import load_wheel_reaction_times_local
from brainbox.behavior.training import *

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
for datepath in os.listdir(subject_dir):
    if '202' not in datepath:
        continue
    print(os.path.join(subject_dir, datepath))
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+6:]
    session_count = 0
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue
        session_path = datedir + '\\' + dir
        try:
            temp_trial_data = load_object(session_path+'\\alf', 'trials')
            break
        except:
            print('processing data for '+date)
        try:
            trials, wheel, output_files = extract_all(session_path, save=True)
        except:
            continue
# Out:
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-22
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-26
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-28
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-29
# processing data for 024-08-29
# 2024-09-30 15:16:56.486 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-29\001: Missing ALL !! BNC2 TTLs (187 trials)
# 2024-09-30 15:16:56.500 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:07.871 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-29\001: Missing ALL !! BNC2 TTLs (187 trials)
# 2024-09-30 15:17:07.877 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:07.879 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 187 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-30
# processing data for 024-08-30
# 2024-09-30 15:17:10.618 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-30\001: Missing ALL !! BNC2 TTLs (198 trials)
# 2024-09-30 15:17:10.631 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:23.453 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-30\001: Missing ALL !! BNC2 TTLs (198 trials)
# 2024-09-30 15:17:23.467 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:23.470 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 198 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-02
# processing data for 024-09-02
# 2024-09-30 15:17:26.231 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-02\001: Missing ALL !! BNC2 TTLs (215 trials)
# 2024-09-30 15:17:26.251 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:38.509 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-02\001: Missing ALL !! BNC2 TTLs (215 trials)
# 2024-09-30 15:17:38.516 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:38.518 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 215 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-03
# processing data for 024-09-03
# 2024-09-30 15:17:40.631 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-03\001: Missing ALL !! BNC2 TTLs (180 trials)
# 2024-09-30 15:17:40.647 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:40.821 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 170022  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-03\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# 2024-09-30 15:17:52.277 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-03\001: Missing ALL !! BNC2 TTLs (180 trials)
# 2024-09-30 15:17:52.283 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:17:52.285 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 180 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-04
# processing data for 024-09-04
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-05
# processing data for 024-09-05
# 2024-09-30 15:18:09.933 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-05\002: Missing ALL !! BNC2 TTLs (219 trials)
# 2024-09-30 15:18:09.952 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:18:23.329 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-05\002: Missing ALL !! BNC2 TTLs (219 trials)
# 2024-09-30 15:18:23.337 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:18:23.338 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 219 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-06
# processing data for 024-09-06
# 2024-09-30 15:18:25.384 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-06\002: Missing ALL !! BNC2 TTLs (205 trials)
# 2024-09-30 15:18:25.408 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:18:36.822 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-06\002: Missing ALL !! BNC2 TTLs (205 trials)
# 2024-09-30 15:18:36.829 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:18:36.831 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 205 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-09
# processing data for 024-09-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-10
# processing data for 024-09-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-11
# processing data for 024-09-11
# 2024-09-30 15:18:59.13 WARNING  [training_alt_trials.py:347] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-11\002: Missing ALL !! BNC2 TTLs (262 trials)
# 2024-09-30 15:18:59.54 WARNING  [training_alt_trials.py:211] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:18:59.251 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 66170  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-11\002\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# 2024-09-30 15:19:12.994 WARNING  [training_trials.py:337] Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-11\002: Missing ALL !! BNC2 TTLs (262 trials)
# 2024-09-30 15:19:13.1 WARNING  [training_trials.py:197] No BNC2 for feedback times, filling error trials NaNs
# 2024-09-30 15:19:13.3 WARNING  [training_wheel.py:368] no reliable goCue/Feedback times (both needed) for 262 trials
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-12
# processing data for 024-09-12
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-13
# processing data for 024-09-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-16
# processing data for 024-09-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-17
# processing data for 024-09-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-18
# processing data for 024-09-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-19
# processing data for 024-09-19
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-20
# processing data for 024-09-20
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-23
# processing data for 024-09-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-24
# processing data for 024-09-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-25
# processing data for 024-09-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-26
# processing data for 024-09-26
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-27
# processing data for 024-09-27

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
trials_by_day = []
numTrial_by_day = []
all_trials={}
for datepath in os.listdir(subject_dir):
    print(os.path.join(subject_dir, datepath))
    if '202' not in datepath:
        continue
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+5:]
    session_count = 0
    trial_data = []
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue

        session_path = datedir + '\\' + dir
        print(session_path)
        temp_trial_data = load_object(session_path+'\\alf', 'trials')
        numTrial = len(temp_trial_data['repNum'])
        
        # # Replace nans with zeros
        temp_trial_data.contrastRight[np.isnan(temp_trial_data.contrastRight)] = 0
        temp_trial_data.contrastLeft[np.isnan(temp_trial_data.contrastLeft)] = 0

        if session_count == 0:
            trial_data = temp_trial_data
        else:
            
            for k in trial_data.keys():
                trial_data[k] = np.concatenate(list(d[k] for d in [trial_data, temp_trial_data]))
        session_count += 1
        print('Number of trials in session#' + str(session_count) + ': ' + str(numTrial) )
    all_trials.update({date:trial_data})
    if os.path.exists(os.path.join(datedir, 'reaction_time.png')):
        continue
    # rt = trial_data['firstMovement_times'] - trial_data['stimOnTrigger_times']
    # plt.figure()
    # plt.plot(range(1,len(rt)+1), rt)
    # plt.title(subject_id+' '+date)
    # plt.xlabel('Trial#')
    # plt.ylabel('reaction time (s)')
    # plt.savefig(datedir+'\\reaction_time.png')
    #plt.show()

    # psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
    # plt.title(subject_id+' '+date)
    # psych_fig.savefig(datedir+'\\psychometric_curve.png')

    trial_correct_hist, bin_edges = np.histogram(np.where(trial_data['feedbackType'] == 1), bins=range(0, len(trial_data['feedbackType'])+1, 20))
    trial_correct_frac =  trial_correct_hist /20

    # plt.figure()
    # plt.plot(bin_edges[1:], trial_correct_frac, '-o')
    # plt.title(subject_id+' '+date)
    # plt.xlabel('20 trial blocks')
    # plt.ylabel('Percentage correct')
    # plt.savefig(datedir+'\\session_correct_progression.png')
    #plt.show()

#trials_all = concatenate_trials(all_trials)
# Out:
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-29
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-29\001
# Number of trials in session#1: 187
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-30
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-08-30\001
# Number of trials in session#1: 198
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-02
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-02\001
# Number of trials in session#1: 215
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-03\001
# Number of trials in session#1: 180
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-04
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-04\001
# Number of trials in session#1: 195
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-05
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-05\002
# Number of trials in session#1: 219
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-06\002
# Number of trials in session#1: 205
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-09\001
# Number of trials in session#1: 230
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-10\001
# Number of trials in session#1: 84
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-11\002
# Number of trials in session#1: 262
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-12
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-12\001
# Number of trials in session#1: 250
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-13\002
# Number of trials in session#1: 241
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-16\002
# Number of trials in session#1: 278
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-17\002
# Number of trials in session#1: 227
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-18\002
# Number of trials in session#1: 201
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-19
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-19\002
# Number of trials in session#1: 245
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-20
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-20\002
# Number of trials in session#1: 166
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-23\002
# Number of trials in session#1: 205
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-24\001
# Number of trials in session#1: 252
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-25\001
# Number of trials in session#1: 256
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-26
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-26\001
# Number of trials in session#1: 206
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\L_R3\2024-09-27\002
# Number of trials in session#1: 219

# %%
accuracies = []
accuracies_vis = []
accuracies_aud = []
num_trials = []
for trials in all_trials.values():
    #print(np.sum(trials['feedbackType'] == 1))
    #print(len(trials))
    try:
        accuracies.append(np.sum(trials['feedbackType'] == 1)/len(trials['feedbackType']))        
        accuracies_vis.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==0))/np.sum(trials['modality']==0))
        accuracies_aud.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==1))/np.sum(trials['modality']==1))
        num_trials.append(len(trials['feedbackType']))
    except:
        continue

# %%
accuracies_vis
# Out:
# [0.58,
#  0.47692307692307695,
#  0.5154639175257731,
#  0.4892086330935252,
#  0.42342342342342343,
#  0.3611111111111111,
#  0.37142857142857144,
#  0.28688524590163933,
#  0.39072847682119205,
#  0.4,
#  0.4533333333333333,
#  0.35333333333333333,
#  0.47619047619047616,
#  0.3586206896551724,
#  0.5107913669064749,
#  0.41875,
#  0.49375,
#  0.3416149068322981,
#  0.45294117647058824,
#  0.5217391304347826,
#  0.4842105263157895,
#  0.5460122699386503,
#  0.5722222222222222,
#  0.52046783625731,
#  0.6352941176470588,
#  0.5789473684210527,
#  0.5857142857142857,
#  0.6933333333333334,
#  0.65,
#  0.6866666666666666,
#  0.5461538461538461,
#  0.7175572519083969,
#  0.6638655462184874,
#  0.6294117647058823,
#  0.7769230769230769,
#  0.7416666666666667,
#  0.6923076923076923,
#  0.81875,
#  0.80625,
#  0.727810650887574,
#  0.38,
#  0.6818181818181818,
#  0.7166666666666667,
#  0.7066666666666667,
#  0.6933333333333334,
#  0.7588235294117647,
#  0.36134453781512604,
#  0.3,
#  0.6428571428571429,
#  0.7176470588235294,
#  0.6611570247933884,
#  0.675,
#  0.7142857142857143,
#  0.7588235294117647,
#  0.6133333333333333]

# %%
# Plotting
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot lines and scatter points on the first axis
days = np.arange(1, len(num_trials) + 1)
axs[0].plot(days, accuracies_vis, label='vis trials', color='blue')
axs[0].scatter(days, accuracies_vis, color='blue')
axs[0].plot(days, accuracies_aud, label='aud trials', color='orange')
axs[0].scatter(days, accuracies_aud, color='orange')
axs[0].set_ylabel('Correct Choice %')
axs[0].set_xlabel('Training Days')
axs[0].set_xticks(np.arange(1, len(num_trials) + 1, 5))
#axs[0].set_yticklabels([str(x) for x in range(0,101,20)])
axs[0].set_title(subject_id)
axs[0].legend()

axs[1].plot(days, num_trials, color='green', marker='o')
axs[1].set_ylabel('Number of Trials')
axs[1].set_xlabel('Training Days')
axs[1].set_xticks(np.arange(1, len(num_trials) + 1, 5))


plt.tight_layout()


plt.savefig(os.path.join(subject_dir, 'training_summary.png'),dpi=300)

# %%
stages = ['Trial Start', 'Stimulus Presentation', 'Response Window', 'Decision and Feedback', 'Inter-Trial Interval']
durations = [1, 2, 1, 1, 2]  # Example durations in seconds

# Calculate the cumulative end times for each stage
end_times = [sum(durations[:i+1]) for i in range(len(durations))]
start_times = [0] + end_times[:-1]

# Create the plot
fig, ax = plt.subplots(figsize=(12, 2))

# Plot each stage as a horizontal line segment
for start, end, stage in zip(start_times, end_times, stages):
    ax.plot([start, end], [0.5, 0.5], marker='|', markersize=20, color='tab:blue')
    ax.text((start + end) / 2, 0.55, stage, ha='center', va='bottom', fontsize=10)

# Formatting the plot
ax.set_ylim(0, 1)
ax.set_yticks([])
ax.set_xlim(0, end_times[-1])
ax.set_xticks(start_times + [end_times[-1]])
ax.set_xticklabels(start_times + [end_times[-1]])
ax.set_xlabel('Time (s)')
ax.set_title('IBL Decision-Making Task Structure in a Trial')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### The movements algorithm
# The wheel movement onsets and offsets are calculated using the `wheel.movements` function.  The output of this function is saved in the 'wheelMoves' ALF.
#
# Refer to the `wheel.movements` function docstring for details of how the movements are detected.  In addition to the data found in the wheelMoves object, the function outputs an array of peak velocity times.  Also the function has a `make_plots` flag which will produce plots of the wheel position and velocity with the movement onsets and offsets highlighted (see below).
#
# The movements algorithm requires the positions and timestamps to be evenly sampled so they should be interpolated first, which can be done with the `wheel.interpolate_position` function.  The default sampling frequency is 1000Hz:

# %%
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position)
sec = 1000  # Number of seconds to plot
plt.figure()

# Plot the interpolated data points
mask = t < (t[0] + sec)
plt.plot(t[mask], pos[mask], '.', markeredgecolor='lightgrey', markersize=1)

# Plot the original data
mask = wheel.timestamps < (wheel.timestamps[0] + sec)
plt.plot(wheel.timestamps[mask], wheel.position[mask], 'r+', markersize=6)

# Labels etc.
plt.xlabel('time / sec')
plt.ylabel('position / rad')
plt.box(on=None)
plt.show()

# %%
# Convert the pos threshold defaults from samples to correct unit
thresholds_cm = wh.samples_to_cm(np.array([8, 1.5]), resolution=wh.ENC_RES)
thresholds = wh.cm_to_rad(thresholds_cm)
mask = t < (t[0] + sec)

onsets, offsets, peak_amp, peak_vel_times = wh.movements(
    t[mask], pos[mask], pos_thresh=thresholds[0], pos_thresh_onset=thresholds[0], make_plots=True)
plt.show()

# %%
rt = load_wheel_reaction_times_local(session_path+'\\alf')
trial_data = load_object(session_path+'\\alf', 'trials')

# # Replace nans with zeros
trial_data.contrastRight[np.isnan(trial_data.contrastRight)] = 0
trial_data.contrastLeft[np.isnan(trial_data.contrastLeft)] = 0

contrast = trial_data.contrastRight - trial_data.contrastLeft
mean_rt = [np.nanmean(rt[contrast == c]) for c in set(contrast)]

# RT may be nan if there were no detected movements, or if the goCue or stimOn times were nan
xdata = np.unique(contrast)
plt.figure(figsize=(4, 3))  # Some sort of strange behaviour in this cell's output
plt.plot(xdata, mean_rt);

plt.xlabel('contrast')
plt.ylabel('mean rt / s')
plt.ylim(bottom=0);
plt.show()

# %%
Fs = 1000
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position, freq=Fs)
vel, acc = wh.velocity_smoothed(pos, Fs)
n = 50
on, off = wheel_moves['intervals'][n,]
mask = np.logical_and(t > on, t < off)
sng = np.sign(vel[mask])
idx, = np.where(np.diff(sng) != 0)

plt.figure()
plt.plot(t[mask], pos[mask], 'k')
for i in idx:
    plt.axvline(x=t[mask][i], color='k', linestyle=':')

plt.title('Movement #%s' % n)
plt.xlabel('time / s')
plt.ylabel('position / rad');
plt.show()

# %%
n_trials = 5  # Number of trials to plot
# Randomly select the trials to plot
trial_ids = np.random.randint(trial_data['choice'].size, size=n_trials)
fig, axs = plt.subplots(1, n_trials, figsize=(8.5,2.5))
plt.tight_layout()

# Plot go cue and response times
goCues = trial_data['goCue_times'][trial_ids]
responses = trial_data['response_times'][trial_ids]

# Plot traces between trial intervals
starts = trial_data['intervals'][trial_ids, 0]
ends = trial_data['intervals'][trial_ids, 1]
# Cut up the wheel vectors
traces = wh.traces_by_trial(t, pos, start=starts, end=ends)
zipped = zip(traces, axs, goCues, responses, trial_ids)

for (trace, ax, go, resp, n) in zipped:
    ax.plot(trace[0], trace[1], 'k-')
    ax.axvline(x=go, color='g', label='go cue', linestyle=':')
    ax.axvline(x=resp, color='r', label='threshold', linestyle=':')
    ax.set_title('Trial #%s' % n)

    # Turn off tick labels
    ax.set_yticklabels([])
    ax.set_xticklabels([])

# Add labels to first
axs[0].set_xlabel('time / sec')
axs[0].set_ylabel('position / rad')
plt.legend();
plt.tight_layout()
plt.show()

# %%
psych = compute_psychometric(trial_data, signed_contrast=None, block=None, plotting=True, compute_ci=False, alpha=0.32)

# %%
psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
plt.title(subject_id+' '+date)
psych_fig.savefig(session_path+'\\psychometric_curve.png')

# %%
plt.plot(range(1,len(rt)+1), rt)
plt.title(subject_id+' '+date)
plt.xlabel('Trial#')
plt.ylabel('reaction time (s)')
plt.savefig(session_path+'\\reaction_time.png')
plt.show()
