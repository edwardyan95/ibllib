# %%
import sys
# sys.path.append(r'C:\Users\edwar\Documents\LabStuff\ibllib\brainbox\io')
#sys.path.append(r'C:\Users\IBL\Documents\ibl_analysis\ONE\one')
import matplotlib.pyplot as plt
import numpy as np
from brainbox.io.one import load_wheel_reaction_times
import brainbox.behavior.wheel as wh
from ibllib.io.raw_data_loaders import *
from ibllib.pipes.tasks import *
from ibllib.pipes import *
from ibllib.io.extractors.bpod_trials import *
from one.api import ONE
from one.alf.io import *

from ibllib.io.extractors.ephys_fpga import extract_wheel_moves
from ibllib.io.extractors.training_wheel import extract_first_movement_times
#from localAlf import load_wheel_reaction_times_local
from brainbox.behavior.training import *

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\M3_8m'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
for datepath in os.listdir(subject_dir):
    if '202' not in datepath:
        continue
    print(os.path.join(subject_dir, datepath))
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+6:]
    session_count = 0
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue
        session_path = datedir + '\\' + dir
        try:
            temp_trial_data = load_object(session_path+'\\alf', 'trials')
            break
        except:
            print('processing data for '+date)
        trials, wheel, output_files = extract_all(session_path, save=True)
# Out:
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-12
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-19
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-20
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-26
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-28
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-30
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-10-31
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-01
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-02
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-08
# processing data for 2023-11-08
# 2023-11-20 22:59:06.771 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 81559  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-08\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-09
# processing data for 2023-11-09
# 2023-11-20 22:59:20.338 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 161945  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-09\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-10
# processing data for 2023-11-10
# 2023-11-20 22:59:37.657 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 12259  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-10\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-13
# processing data for 2023-11-13
# 2023-11-20 22:59:52.547 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 68179  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-13\002\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-14
# processing data for 2023-11-14
# 2023-11-20 23:00:04.815 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 144932  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-14\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-15
# processing data for 2023-11-15
# 2023-11-20 23:00:19.935 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 370197  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-15\002\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AG_R3\2023-11-17
# processing data for 2023-11-17

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
trials_by_day = []
numTrial_by_day = []
all_trials={}
for datepath in os.listdir(subject_dir):
    print(os.path.join(subject_dir, datepath))
    if '202' not in datepath:
        continue
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+6:]
    session_count = 0
    trial_data = []
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue

        session_path = datedir + '\\' + dir
        temp_trial_data = load_object(session_path+'\\alf', 'trials')
        numTrial = len(temp_trial_data['repNum'])
        
        # # Replace nans with zeros
        temp_trial_data.contrastRight[np.isnan(temp_trial_data.contrastRight)] = 0
        temp_trial_data.contrastLeft[np.isnan(temp_trial_data.contrastLeft)] = 0

        if session_count == 0:
            trial_data = temp_trial_data
        else:
            
            for k in trial_data.keys():
                trial_data[k] = np.concatenate(list(d[k] for d in [trial_data, temp_trial_data]))
        session_count += 1
        print('Number of trials in session#' + str(session_count) + ': ' + str(numTrial) )
    all_trials.update({date:trial_data})
    if os.path.exists(os.path.join(datedir, 'reaction_time.png')):
        continue
    rt = trial_data['firstMovement_times'] - trial_data['goCue_times']
    plt.figure()
    plt.plot(range(1,len(rt)+1), rt)
    plt.title(subject_id+' '+date)
    plt.xlabel('Trial#')
    plt.ylabel('reaction time (s)')
    plt.savefig(datedir+'\\reaction_time.png')
    #plt.show()

    psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
    plt.title(subject_id+' '+date)
    psych_fig.savefig(datedir+'\\psychometric_curve.png')

    trial_correct_hist, bin_edges = np.histogram(np.where(trial_data['feedbackType'] == 1), bins=range(0, len(trial_data['feedbackType'])+1, 20))
    trial_correct_frac =  trial_correct_hist /20

    plt.figure()
    plt.plot(bin_edges[1:], trial_correct_frac, '-o')
    plt.title(subject_id+' '+date)
    plt.xlabel('20 trial blocks')
    plt.ylabel('Percentage correct')
    plt.savefig(datedir+'\\session_correct_progression.png')
    #plt.show()

#trials_all = concatenate_trials(all_trials)
# Out:
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-09-25
# Number of trials in session#1: 153
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-09-26
# Number of trials in session#1: 166
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-09-27
# Number of trials in session#1: 275
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-09-28
# Number of trials in session#1: 255
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-09-29
# Number of trials in session#1: 245
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-09-30
# Number of trials in session#1: 192
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-02
# Number of trials in session#1: 376
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-03
# Number of trials in session#1: 154
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-04
# Number of trials in session#1: 389
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-05
# Number of trials in session#1: 150
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-06
# Number of trials in session#1: 282
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-09
# Number of trials in session#1: 238
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-10
# Number of trials in session#1: 189
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-11
# Number of trials in session#1: 322
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-12
# Number of trials in session#1: 274
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-13
# Number of trials in session#1: 200
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-14
# Number of trials in session#1: 292
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-16
# Number of trials in session#1: 311
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-17
# Number of trials in session#1: 346
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-18
# Number of trials in session#1: 437
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-19
# Number of trials in session#1: 434
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-20
# Number of trials in session#1: 455
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-23
# Number of trials in session#1: 413
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-24
# Number of trials in session#1: 326
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-25
# Number of trials in session#1: 410
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-26
# Number of trials in session#1: 304
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-27
# Number of trials in session#1: 313
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-30
# Number of trials in session#1: 427
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-10-31
# Number of trials in session#1: 356
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-01
# Number of trials in session#1: 305
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-02
# Number of trials in session#1: 400
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-03
# Number of trials in session#1: 237
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-04
# Number of trials in session#1: 356
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-06
# Number of trials in session#1: 371
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-07
# Number of trials in session#1: 334
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-08
# Number of trials in session#1: 355
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-09
# Number of trials in session#1: 405
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-10
# Number of trials in session#1: 298
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-13
# Number of trials in session#1: 74
# Number of trials in session#2: 212
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-14
# Number of trials in session#1: 218
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-15
# Number of trials in session#1: 341
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\2023-11-17
# Number of trials in session#1: 398
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\habituation
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\AE_L3\training_summary.png

# %%
accuracies = []
accuracies_left = []
accuracies_right = []
num_trials = []
for trials in all_trials.values():
    #print(np.sum(trials['feedbackType'] == 1))
    #print(len(trials))
    accuracies.append(np.sum(trials['feedbackType'] == 1)/len(trials['feedbackType']))        
    accuracies_left.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['contrastLeft']>0.49))/np.sum(trials['contrastLeft']>0.49))
    accuracies_right.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['contrastRight']>0.49))/np.sum(trials['contrastRight']>0.49))
    num_trials.append(len(trials['feedbackType']))

# %%
print(accuracies_right)
# Out:
# [0.1076923076923077, 0.05090909090909091, 0.3333333333333333, 0.25630252100840334, 0.3022222222222222, 0.2682926829268293, 0.37623762376237624, 0.35, 0.3684210526315789, 0.5797872340425532, 0.4230769230769231, 0.4198473282442748, 0.43577981651376146, 0.38095238095238093, 0.45018450184501846, 0.5183673469387755, 0.50625, 0.6033057851239669, 0.6693548387096774, 0.7704280155642024, 0.8376623376623377, 0.8389830508474576, 0.7533632286995515, 0.8520710059171598, 0.9193548387096774, 0.75, 0.7571428571428571, 0.8541666666666666]

# %%
fig, axs = plt.subplots(1,2, figsize=(10,5))
axs[0].plot(np.arange(1,len(num_trials)+1), accuracies_left)
axs[0].plot(np.arange(1,len(num_trials)+1), accuracies_right)
axs[0].set_ylabel('Correct Choice %')
axs[0].set_xlabel('Training Days')
axs[0].set_xticks(np.arange(1,len(num_trials)+1))
axs[0].set_title(subject_id)
axs[0].legend(['Left Stim', 'Right Stim'])

axs[1].bar(np.arange(1,len(num_trials)+1),num_trials)
axs[1].set_ylabel('Number of Trials')
axs[1].set_xlabel('Training Days')
axs[1].set_xticks(np.arange(1,len(num_trials)+1))
plt.tight_layout()


plt.savefig(os.path.join(subject_dir, 'training_summary.png'))

# %% [markdown]
# ### The movements algorithm
# The wheel movement onsets and offsets are calculated using the `wheel.movements` function.  The output of this function is saved in the 'wheelMoves' ALF.
#
# Refer to the `wheel.movements` function docstring for details of how the movements are detected.  In addition to the data found in the wheelMoves object, the function outputs an array of peak velocity times.  Also the function has a `make_plots` flag which will produce plots of the wheel position and velocity with the movement onsets and offsets highlighted (see below).
#
# The movements algorithm requires the positions and timestamps to be evenly sampled so they should be interpolated first, which can be done with the `wheel.interpolate_position` function.  The default sampling frequency is 1000Hz:

# %%
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position)
sec = 1000  # Number of seconds to plot
plt.figure()

# Plot the interpolated data points
mask = t < (t[0] + sec)
plt.plot(t[mask], pos[mask], '.', markeredgecolor='lightgrey', markersize=1)

# Plot the original data
mask = wheel.timestamps < (wheel.timestamps[0] + sec)
plt.plot(wheel.timestamps[mask], wheel.position[mask], 'r+', markersize=6)

# Labels etc.
plt.xlabel('time / sec')
plt.ylabel('position / rad')
plt.box(on=None)
plt.show()

# %%
# Convert the pos threshold defaults from samples to correct unit
thresholds_cm = wh.samples_to_cm(np.array([8, 1.5]), resolution=wh.ENC_RES)
thresholds = wh.cm_to_rad(thresholds_cm)
mask = t < (t[0] + sec)

onsets, offsets, peak_amp, peak_vel_times = wh.movements(
    t[mask], pos[mask], pos_thresh=thresholds[0], pos_thresh_onset=thresholds[0], make_plots=True)
plt.show()

# %%
rt = load_wheel_reaction_times_local(session_path+'\\alf')
trial_data = load_object(session_path+'\\alf', 'trials')

# # Replace nans with zeros
trial_data.contrastRight[np.isnan(trial_data.contrastRight)] = 0
trial_data.contrastLeft[np.isnan(trial_data.contrastLeft)] = 0

contrast = trial_data.contrastRight - trial_data.contrastLeft
mean_rt = [np.nanmean(rt[contrast == c]) for c in set(contrast)]

# RT may be nan if there were no detected movements, or if the goCue or stimOn times were nan
xdata = np.unique(contrast)
plt.figure(figsize=(4, 3))  # Some sort of strange behaviour in this cell's output
plt.plot(xdata, mean_rt);

plt.xlabel('contrast')
plt.ylabel('mean rt / s')
plt.ylim(bottom=0);
plt.show()

# %%
Fs = 1000
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position, freq=Fs)
vel, acc = wh.velocity_smoothed(pos, Fs)
n = 50
on, off = wheel_moves['intervals'][n,]
mask = np.logical_and(t > on, t < off)
sng = np.sign(vel[mask])
idx, = np.where(np.diff(sng) != 0)

plt.figure()
plt.plot(t[mask], pos[mask], 'k')
for i in idx:
    plt.axvline(x=t[mask][i], color='k', linestyle=':')

plt.title('Movement #%s' % n)
plt.xlabel('time / s')
plt.ylabel('position / rad');
plt.show()

# %%
n_trials = 5  # Number of trials to plot
# Randomly select the trials to plot
trial_ids = np.random.randint(trial_data['choice'].size, size=n_trials)
fig, axs = plt.subplots(1, n_trials, figsize=(8.5,2.5))
plt.tight_layout()

# Plot go cue and response times
goCues = trial_data['goCue_times'][trial_ids]
responses = trial_data['response_times'][trial_ids]

# Plot traces between trial intervals
starts = trial_data['intervals'][trial_ids, 0]
ends = trial_data['intervals'][trial_ids, 1]
# Cut up the wheel vectors
traces = wh.traces_by_trial(t, pos, start=starts, end=ends)
zipped = zip(traces, axs, goCues, responses, trial_ids)

for (trace, ax, go, resp, n) in zipped:
    ax.plot(trace[0], trace[1], 'k-')
    ax.axvline(x=go, color='g', label='go cue', linestyle=':')
    ax.axvline(x=resp, color='r', label='threshold', linestyle=':')
    ax.set_title('Trial #%s' % n)

    # Turn off tick labels
    ax.set_yticklabels([])
    ax.set_xticklabels([])

# Add labels to first
axs[0].set_xlabel('time / sec')
axs[0].set_ylabel('position / rad')
plt.legend();
plt.tight_layout()
plt.show()

# %%
psych = compute_psychometric(trial_data, signed_contrast=None, block=None, plotting=True, compute_ci=False, alpha=0.32)

# %%
psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
plt.title(subject_id+' '+date)
psych_fig.savefig(session_path+'\\psychometric_curve.png')

# %%
plt.plot(range(1,len(rt)+1), rt)
plt.title(subject_id+' '+date)
plt.xlabel('Trial#')
plt.ylabel('reaction time (s)')
plt.savefig(session_path+'\\reaction_time.png')
plt.show()
