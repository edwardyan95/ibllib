# %%
import sys
# sys.path.append(r'C:\Users\edwar\Documents\LabStuff\ibllib\brainbox\io')
#sys.path.append(r'C:\Users\IBL\Documents\ibl_analysis\ONE\one')
import matplotlib.pyplot as plt
import numpy as np
from brainbox.io.one import load_wheel_reaction_times
import brainbox.behavior.wheel as wh
from ibllib.io.raw_data_loaders import *
from ibllib.pipes.tasks import *
from ibllib.pipes import *
from ibllib.io.extractors.bpod_trials import *
from one.api import ONE
from one.alf.io import *

from ibllib.io.extractors.ephys_fpga import extract_wheel_moves
from ibllib.io.extractors.training_wheel import extract_first_movement_times
#from localAlf import load_wheel_reaction_times_local
from brainbox.behavior.training import *

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
for datepath in os.listdir(subject_dir):
    if '202' not in datepath:
        continue
    print(os.path.join(subject_dir, datepath))
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+6:]
    session_count = 0
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue
        session_path = datedir + '\\' + dir
        try:
            temp_trial_data = load_object(session_path+'\\alf', 'trials')
            break
        except:
            print('processing data for '+date)
        try:
            trials, wheel, output_files = extract_all(session_path, save=True)
        except:
            continue
# Out:
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-02
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-05
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-09
# processing data for 024-12-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-10
# processing data for 024-12-10
# 2025-03-17 11:37:55.941 WARNING  [raw_data_loaders.py:697] Rotary encoder reset logs events in ms instead of us: RE firmware needs upgrading and wheel velocity is potentially inaccurate
# c:\Users\dirk\anaconda3\envs\iblenv\lib\site-packages\neurodsp\utils.py:54: RankWarning: Polyfit may be poorly conditioned
#   fcn_a2b, _ = _interp_fcn(tsa, tsb, ib)
# c:\Users\dirk\anaconda3\envs\iblenv\lib\site-packages\scipy\interpolate\_interpolate.py:701: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# c:\Users\dirk\anaconda3\envs\iblenv\lib\site-packages\neurodsp\utils.py:66: RankWarning: Polyfit may be poorly conditioned
#   fcn_a2b, drift_ppm = _interp_fcn(tsa, tsb, ib)
# processing data for 024-12-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-11
# processing data for 024-12-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-12
# processing data for 024-12-12
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-13
# processing data for 024-12-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-14
# processing data for 024-12-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-16
# processing data for 024-12-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-17
# processing data for 024-12-17
# processing data for 024-12-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-18
# processing data for 024-12-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-19
# processing data for 024-12-19
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-06
# processing data for 025-01-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-07
# processing data for 025-01-07
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-08
# processing data for 025-01-08
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-09
# processing data for 025-01-09
# processing data for 025-01-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-10
# processing data for 025-01-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-13
# processing data for 025-01-13
# processing data for 025-01-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-14
# processing data for 025-01-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-15
# processing data for 025-01-15
# processing data for 025-01-15
# 2025-03-17 11:41:39.864 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 252514  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-15\003\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-16
# processing data for 025-01-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-17
# processing data for 025-01-17
# processing data for 025-01-17
# processing data for 025-01-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-18
# processing data for 025-01-18
# 2025-03-17 11:42:17.805 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 73061  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-18\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-20
# processing data for 025-01-20
# processing data for 025-01-20
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-21
# processing data for 025-01-21
# 2025-03-17 11:42:40.974 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 10433  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-21\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-22
# processing data for 025-01-22
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-23
# processing data for 025-01-23
# 2025-03-17 11:43:01.678 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 151516  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-23\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-24
# processing data for 025-01-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-25
# processing data for 025-01-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-27
# processing data for 025-01-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-28
# processing data for 025-01-28
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-29
# processing data for 025-01-29
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-03
# processing data for 025-02-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-04
# processing data for 025-02-04
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-05
# processing data for 025-02-05
# 2025-03-17 11:44:26.485 WARNING  [raw_data_loaders.py:655] _iblrig_encoderPositions.raw.ssv rotary encoder timestamps swapped at index: 119007  Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-05\001\raw_behavior_data\_iblrig_encoderPositions.raw.ssv
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-06
# processing data for 025-02-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-07
# processing data for 025-02-07
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-11
# processing data for 025-02-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-14
# processing data for 025-02-14

# %%
subject_dir = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2'
subject_id = subject_dir[subject_dir.find('Subjects')+9:]
# print(subject_id)
trials_by_day = []
numTrial_by_day = []
all_trials={}
for datepath in os.listdir(subject_dir):
    print(os.path.join(subject_dir, datepath))
    if '202' not in datepath:
        continue
    datedir = os.path.join(subject_dir, datepath)
    date = datedir[datedir.find(subject_id)+5:]
    date = date.replace('-','')
    session_count = 0
    trial_data = []
    for dir in os.listdir(datedir):
        if not os.path.exists(os.path.join(datedir, dir, 'raw_behavior_data', 'online_plot.png')):
            continue

        session_path = datedir + '\\' + dir
        print(session_path)
        temp_trial_data = load_object(session_path+'\\alf', 'trials')
        numTrial = len(temp_trial_data['repNum'])
        
        # # Replace nans with zeros
        temp_trial_data.contrastRight[np.isnan(temp_trial_data.contrastRight)] = 0
        temp_trial_data.contrastLeft[np.isnan(temp_trial_data.contrastLeft)] = 0

        if session_count == 0:
            trial_data = temp_trial_data
        else:
            
            for k in trial_data.keys():
                trial_data[k] = np.concatenate(list(d[k] for d in [trial_data, temp_trial_data]))
        session_count += 1
        print('Number of trials in session#' + str(session_count) + ': ' + str(numTrial) )
    
    if len(trial_data) == 0:
        continue
    all_trials.update({date:trial_data})
    if os.path.exists(os.path.join(datedir, 'reaction_time.png')):
        continue
    # rt = trial_data['firstMovement_times'] - trial_data['stimOnTrigger_times']
    # plt.figure()
    # plt.plot(range(1,len(rt)+1), rt)
    # plt.title(subject_id+' '+date)
    # plt.xlabel('Trial#')
    # plt.ylabel('reaction time (s)')
    # plt.savefig(datedir+'\\reaction_time.png')
    #plt.show()

    # psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
    # plt.title(subject_id+' '+date)
    # psych_fig.savefig(datedir+'\\psychometric_curve.png')

    trial_correct_hist, bin_edges = np.histogram(np.where(trial_data['feedbackType'] == 1), bins=range(0, len(trial_data['feedbackType'])+1, 20))
    trial_correct_frac =  trial_correct_hist /20

    # plt.figure()
    # plt.plot(bin_edges[1:], trial_correct_frac, '-o')
    # plt.title(subject_id+' '+date)
    # plt.xlabel('20 trial blocks')
    # plt.ylabel('Percentage correct')
    # plt.savefig(datedir+'\\session_correct_progression.png')
    #plt.show()

#trials_all = concatenate_trials(all_trials)
# Out:
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-02
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-05
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-09\001
# Number of trials in session#1: 184
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-10\002
# Number of trials in session#1: 165
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-11\004
# Number of trials in session#1: 201
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-12
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-12\001
# Number of trials in session#1: 185
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-13\002
# Number of trials in session#1: 162
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-14\001
# Number of trials in session#1: 240
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-16\001
# Number of trials in session#1: 242
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-17\001
# Number of trials in session#1: 10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-17\002
# Number of trials in session#2: 241
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-18\001
# Number of trials in session#1: 262
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-19
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2024-12-19\002
# Number of trials in session#1: 228
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-06\001
# Number of trials in session#1: 122
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-07
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-07\002
# Number of trials in session#1: 151
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-08
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-08\001
# Number of trials in session#1: 243
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-09
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-09\001
# Number of trials in session#1: 36
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-09\002
# Number of trials in session#2: 223
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-10
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-10\001
# Number of trials in session#1: 300
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-13
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-13\001
# Number of trials in session#1: 42
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-13\002
# Number of trials in session#2: 240
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-14\001
# Number of trials in session#1: 290
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-15
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-15\002
# Number of trials in session#1: 30
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-15\003
# Number of trials in session#2: 307
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-16
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-16\001
# Number of trials in session#1: 290
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-17
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-17\001
# Number of trials in session#1: 57
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-17\002
# Number of trials in session#2: 125
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-17\003
# Number of trials in session#3: 127
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-18
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-18\001
# Number of trials in session#1: 267
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-20
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-20\002
# Number of trials in session#1: 96
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-20\003
# Number of trials in session#2: 175
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-21
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-21\001
# Number of trials in session#1: 220
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-22
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-22\001
# Number of trials in session#1: 201
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-23
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-23\001
# Number of trials in session#1: 280
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-24
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-24\001
# Number of trials in session#1: 257
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-25
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-25\001
# Number of trials in session#1: 356
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-27
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-27\002
# Number of trials in session#1: 267
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-28
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-28\002
# Number of trials in session#1: 278
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-29
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-01-29\001
# Number of trials in session#1: 252
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-03
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-03\001
# Number of trials in session#1: 305
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-04
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-04\001
# Number of trials in session#1: 301
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-05
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-05\001
# Number of trials in session#1: 332
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-06
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-06\001
# Number of trials in session#1: 349
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-07
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-07\001
# Number of trials in session#1: 348
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-11
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-11\001
# Number of trials in session#1: 360
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-14
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\2025-02-14\002
# Number of trials in session#1: 331
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\accuracies_aud.npy
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\accuracies_vis.npy
# Z:\TM_Lab\Edward\Data\iblrig_data\Subjects\R_L2\num_trials.npy

# %%
accuracies = []
accuracies_vis = []
accuracies_aud = []
num_trials = []
training_dates = []
for date, trials in all_trials.items():
    #print(np.sum(trials['feedbackType'] == 1))
    #print(len(trials))
    if len(trials['feedbackType'])<50:
        continue
    try:
        accuracies.append(np.sum(trials['feedbackType'] == 1)/len(trials['feedbackType']))        
        accuracies_vis.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==0))/np.sum(trials['modality']==0))
        accuracies_aud.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==1))/np.sum(trials['modality']==1))
        num_trials.append(len(trials['feedbackType']))
        training_dates.append(date)
    except:
        continue
assert(len(training_dates)==len(accuracies_vis))
np.save(os.path.join(subject_dir, 'accuracies_vis.npy'), np.array(accuracies_vis)) 
np.save(os.path.join(subject_dir, 'accuracies_aud.npy'), np.array(accuracies_aud))
np.save(os.path.join(subject_dir, 'num_trials.npy'), np.array(num_trials))  
np.save(os.path.join(subject_dir, 'training_dates.npy'), np.array(training_dates))

# %%
training_dates.pop(-1)
training_dates
# Out:
# ['2024-10-25',
#  '2024-10-28',
#  '2024-10-29',
#  '2024-10-31',
#  '2024-11-01',
#  '2024-11-04',
#  '2024-11-05',
#  '2024-11-06',
#  '2024-11-07',
#  '2024-11-08',
#  '2024-11-11',
#  '2024-11-12',
#  '2024-11-13',
#  '2024-11-14',
#  '2024-11-18',
#  '2024-11-19',
#  '2024-11-20',
#  '2024-11-22',
#  '2024-11-25',
#  '2024-11-26',
#  '2024-11-27',
#  '2024-11-28',
#  '2024-11-29',
#  '2024-12-02',
#  '2024-12-03',
#  '2024-12-04',
#  '2024-12-05',
#  '2024-12-06',
#  '2024-12-09',
#  '2024-12-10',
#  '2024-12-11',
#  '2024-12-12',
#  '2024-12-13',
#  '2024-12-16',
#  '2024-12-17',
#  '2024-12-19']

# %%
accuracies = []
accuracies_vis = []
accuracies_aud = []
num_trials = []
for trials in all_trials.values():
    #print(np.sum(trials['feedbackType'] == 1))
    #print(len(trials))
    try:
        accuracies.append(np.sum(trials['feedbackType'] == 1)/len(trials['feedbackType']))        
        accuracies_vis.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==0))/np.sum(trials['modality']==0))
        accuracies_aud.append(np.sum(np.logical_and(trials['feedbackType'] == 1, trials['modality']==1))/np.sum(trials['modality']==1))
        num_trials.append(len(trials['feedbackType']))
    except:
        continue
np.save(os.path.join(subject_dir, 'accuracies_vis.npy'), np.array(accuracies_vis)) 
np.save(os.path.join(subject_dir, 'accuracies_aud.npy'), np.array(accuracies_aud))
np.save(os.path.join(subject_dir, 'num_trials.npy'), np.array(num_trials))

# %%
mouse_ids = [
#              'A_L2',
#              'A_R2',
#              'A_R3',
             'O_R2',
             'L_R2',
             'J_L2',
             'R_L2']
behav_data_folder = r'Z:\TM_Lab\Edward\Data\iblrig_data\Subjects'
all_acc_vis = []
all_acc_aud = []
all_num_trials = []
for mouse in mouse_ids:
    mouse_path = os.path.join(behav_data_folder, mouse)
    acc_vis = np.load(os.path.join(mouse_path, 'accuracies_vis.npy'))
    acc_aud = np.load(os.path.join(mouse_path, 'accuracies_aud.npy'))
    num_trials = np.load(os.path.join(mouse_path, 'num_trials.npy'))
    all_acc_vis.append(acc_vis)
    all_acc_aud.append(acc_aud)
    all_num_trials.append(num_trials)

# %%
max_length = 40

# Step 1: Clip or pad arrays to ensure all have the same length
def clip_or_pad(arr, max_length):
    return arr[:max_length] if len(arr) > max_length else np.pad(arr, (0, max_length - len(arr)), constant_values=np.nan)

all_acc_vis = np.array([clip_or_pad(arr, max_length) for arr in all_acc_vis])
all_acc_aud = np.array([clip_or_pad(arr, max_length) for arr in all_acc_aud])
#all_num_trials = np.array([clip_or_pad(arr, max_length) for arr in all_num_trials])

# Step 2: Compute the average and standard error for visual condition
avg_acc_vis = np.nanmean(all_acc_vis, axis=0)
se_acc_vis = np.nanstd(all_acc_vis, axis=0) / np.sqrt(np.sum(~np.isnan(all_acc_vis), axis=0))
avg_acc_aud = np.nanmean(all_acc_aud, axis=0)
se_acc_aud = np.nanstd(all_acc_aud, axis=0) / np.sqrt(np.sum(~np.isnan(all_acc_aud), axis=0))
# Step 3: Plot the average with shaded standard error
x = np.arange(max_length)
plt.plot(x, avg_acc_vis, marker='o', color='blue', label = 'visual trials')
plt.fill_between(x, avg_acc_vis - se_acc_vis, avg_acc_vis + se_acc_vis, color='blue', alpha=0.3)
plt.plot(x, avg_acc_aud, marker='o', color='orange', label = 'auditory trials')
plt.fill_between(x, avg_acc_aud - se_acc_aud, avg_acc_aud + se_acc_aud, color='orange', alpha=0.3)
plt.xlabel('Days')
plt.ylabel('Correct%')
plt.title('Training Performance (4 mice)')
plt.legend()
plt.grid()
plt.show()

# %%
len(all_acc_vis[5])
# Out:
# 60

# %%
subdir = [d for d in os.listdir(subject_dir)]
img_dates = [s for s in subdir if s.isdigit()]

# %%
training_dates
# Out:
# ['20240828',
#  '20240829',
#  '20240830',
#  '20240902',
#  '20240903',
#  '20240904',
#  '20240905',
#  '20240906',
#  '20240909',
#  '20240910',
#  '20240911',
#  '20240912',
#  '20240913',
#  '20240916',
#  '20240917',
#  '20240918',
#  '20240919',
#  '20240920',
#  '20240923',
#  '20240925',
#  '20240926',
#  '20240927',
#  '20240930',
#  '20241001',
#  '20241002',
#  '20241003',
#  '20241004',
#  '20241008',
#  '20241010',
#  '20241011',
#  '20241014',
#  '20241015',
#  '20241017',
#  '20241021',
#  '20241022',
#  '20241024',
#  '20241025',
#  '20241028',
#  '20241029',
#  '20241030',
#  '20241031',
#  '20241101',
#  '20241104',
#  '20241105',
#  '20241107',
#  '20241108',
#  '20241112']

# %%
training_dates = [element.replace('-', '') for element in training_dates]
imgday_indices = [training_dates.index(element) for element in img_dates]
# Plotting
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot lines and scatter points on the first axis
days = np.arange(1, len(num_trials) + 1)
axs[0].plot(days, accuracies_vis, label='vis trials', color='blue')
axs[0].scatter(days, accuracies_vis, color='blue')
axs[0].plot(days, accuracies_aud, label='aud trials', color='orange')
axs[0].scatter(days, accuracies_aud, color='orange')
axs[0].set_ylabel('Correct Choice %')
axs[0].set_xlabel('Training Days')
axs[0].set_xticks(np.arange(1, len(num_trials) + 1, 5))
#axs[0].set_yticklabels([str(x) for x in range(0,101,20)])
axs[0].set_title(subject_id)
axs[0].legend()

axs[1].plot(days, num_trials, color='green', marker='o')
axs[1].set_ylabel('Number of Trials')
axs[1].set_xlabel('Training Days')
axs[1].set_xticks(np.arange(1, len(num_trials) + 1, 5))
for ind in imgday_indices:
    axs[0].axvline(x=ind, color='red', linestyle='--')

plt.tight_layout()


plt.savefig(os.path.join(subject_dir, 'training_summary.png'),dpi=300)

# %%
stages = ['Trial Start', 'Stimulus Presentation', 'Response Window', 'Decision and Feedback', 'Inter-Trial Interval']
durations = [1, 2, 1, 1, 2]  # Example durations in seconds

# Calculate the cumulative end times for each stage
end_times = [sum(durations[:i+1]) for i in range(len(durations))]
start_times = [0] + end_times[:-1]

# Create the plot
fig, ax = plt.subplots(figsize=(12, 2))

# Plot each stage as a horizontal line segment
for start, end, stage in zip(start_times, end_times, stages):
    ax.plot([start, end], [0.5, 0.5], marker='|', markersize=20, color='tab:blue')
    ax.text((start + end) / 2, 0.55, stage, ha='center', va='bottom', fontsize=10)

# Formatting the plot
ax.set_ylim(0, 1)
ax.set_yticks([])
ax.set_xlim(0, end_times[-1])
ax.set_xticks(start_times + [end_times[-1]])
ax.set_xticklabels(start_times + [end_times[-1]])
ax.set_xlabel('Time (s)')
ax.set_title('IBL Decision-Making Task Structure in a Trial')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### The movements algorithm
# The wheel movement onsets and offsets are calculated using the `wheel.movements` function.  The output of this function is saved in the 'wheelMoves' ALF.
#
# Refer to the `wheel.movements` function docstring for details of how the movements are detected.  In addition to the data found in the wheelMoves object, the function outputs an array of peak velocity times.  Also the function has a `make_plots` flag which will produce plots of the wheel position and velocity with the movement onsets and offsets highlighted (see below).
#
# The movements algorithm requires the positions and timestamps to be evenly sampled so they should be interpolated first, which can be done with the `wheel.interpolate_position` function.  The default sampling frequency is 1000Hz:

# %%
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position)
sec = 1000  # Number of seconds to plot
plt.figure()

# Plot the interpolated data points
mask = t < (t[0] + sec)
plt.plot(t[mask], pos[mask], '.', markeredgecolor='lightgrey', markersize=1)

# Plot the original data
mask = wheel.timestamps < (wheel.timestamps[0] + sec)
plt.plot(wheel.timestamps[mask], wheel.position[mask], 'r+', markersize=6)

# Labels etc.
plt.xlabel('time / sec')
plt.ylabel('position / rad')
plt.box(on=None)
plt.show()

# %%
# Convert the pos threshold defaults from samples to correct unit
thresholds_cm = wh.samples_to_cm(np.array([8, 1.5]), resolution=wh.ENC_RES)
thresholds = wh.cm_to_rad(thresholds_cm)
mask = t < (t[0] + sec)

onsets, offsets, peak_amp, peak_vel_times = wh.movements(
    t[mask], pos[mask], pos_thresh=thresholds[0], pos_thresh_onset=thresholds[0], make_plots=True)
plt.show()

# %%
rt = load_wheel_reaction_times_local(session_path+'\\alf')
trial_data = load_object(session_path+'\\alf', 'trials')

# # Replace nans with zeros
trial_data.contrastRight[np.isnan(trial_data.contrastRight)] = 0
trial_data.contrastLeft[np.isnan(trial_data.contrastLeft)] = 0

contrast = trial_data.contrastRight - trial_data.contrastLeft
mean_rt = [np.nanmean(rt[contrast == c]) for c in set(contrast)]

# RT may be nan if there were no detected movements, or if the goCue or stimOn times were nan
xdata = np.unique(contrast)
plt.figure(figsize=(4, 3))  # Some sort of strange behaviour in this cell's output
plt.plot(xdata, mean_rt);

plt.xlabel('contrast')
plt.ylabel('mean rt / s')
plt.ylim(bottom=0);
plt.show()

# %%
Fs = 1000
pos, t = wh.interpolate_position(wheel.timestamps, wheel.position, freq=Fs)
vel, acc = wh.velocity_smoothed(pos, Fs)
n = 50
on, off = wheel_moves['intervals'][n,]
mask = np.logical_and(t > on, t < off)
sng = np.sign(vel[mask])
idx, = np.where(np.diff(sng) != 0)

plt.figure()
plt.plot(t[mask], pos[mask], 'k')
for i in idx:
    plt.axvline(x=t[mask][i], color='k', linestyle=':')

plt.title('Movement #%s' % n)
plt.xlabel('time / s')
plt.ylabel('position / rad');
plt.show()

# %%
n_trials = 5  # Number of trials to plot
# Randomly select the trials to plot
trial_ids = np.random.randint(trial_data['choice'].size, size=n_trials)
fig, axs = plt.subplots(1, n_trials, figsize=(8.5,2.5))
plt.tight_layout()

# Plot go cue and response times
goCues = trial_data['goCue_times'][trial_ids]
responses = trial_data['response_times'][trial_ids]

# Plot traces between trial intervals
starts = trial_data['intervals'][trial_ids, 0]
ends = trial_data['intervals'][trial_ids, 1]
# Cut up the wheel vectors
traces = wh.traces_by_trial(t, pos, start=starts, end=ends)
zipped = zip(traces, axs, goCues, responses, trial_ids)

for (trace, ax, go, resp, n) in zipped:
    ax.plot(trace[0], trace[1], 'k-')
    ax.axvline(x=go, color='g', label='go cue', linestyle=':')
    ax.axvline(x=resp, color='r', label='threshold', linestyle=':')
    ax.set_title('Trial #%s' % n)

    # Turn off tick labels
    ax.set_yticklabels([])
    ax.set_xticklabels([])

# Add labels to first
axs[0].set_xlabel('time / sec')
axs[0].set_ylabel('position / rad')
plt.legend();
plt.tight_layout()
plt.show()

# %%
psych = compute_psychometric(trial_data, signed_contrast=None, block=None, plotting=True, compute_ci=False, alpha=0.32)

# %%
psych_fig, psych_ax = plot_psychometric(trial_data, ax=None, title=None, plot_ci=False, ci_aplha=0.32)
plt.title(subject_id+' '+date)
psych_fig.savefig(session_path+'\\psychometric_curve.png')

# %%
plt.plot(range(1,len(rt)+1), rt)
plt.title(subject_id+' '+date)
plt.xlabel('Trial#')
plt.ylabel('reaction time (s)')
plt.savefig(session_path+'\\reaction_time.png')
plt.show()
